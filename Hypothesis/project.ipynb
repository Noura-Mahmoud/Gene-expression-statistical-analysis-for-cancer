# %%
import pandas as pd
from scipy.stats import ttest_ind, ttest_rel
from statsmodels.stats.multitest import multipletests

healthy = pd.read_csv('data/lusc-rsem-fpkm-tcga_paired.txt', sep='\t')
cancer = pd.read_csv('data/lusc-rsem-fpkm-tcga-t_paired.txt', sep='\t')
pd.options.display.max_columns = None

# %%
healthy.to_csv("data/healthy.csv")

# %%
cancer.to_csv("data/cancer.csv")

# %%
healthy1 = healthy[healthy.astype(bool).sum(1)>27]
cancer1 = cancer[healthy.astype(bool).sum(1)>27]

healthy2 = healthy1[cancer1.astype(bool).sum(1)>27]
cancer2 = cancer1[cancer1.astype(bool).sum(1)>27]

# %%
healthy2.to_csv("data/healthy2.csv")

# %%
healthy2
# Out:
#          Hugo_Symbol  Entrez_Gene_Id  TCGA-43-7657  TCGA-58-8386  \
# 0           HIST3H2A           92815         62.12        130.60
# 1              LIN7B           64130        185.11        283.05
# 2                LXN           56925        909.17        819.30
# 3             CNKSR2           22866         41.81         18.29
# 4              SCML1            6322        133.36        214.27
# ...              ...             ...           ...           ...
# 19641         ZNF521           25925        215.77        148.09
# 19642         SPINT2           10653       6792.79       5441.30
# 19643         HAVCR2           84868        423.61        529.06
# 19646  CTD-2116N17.1               0          0.00          0.00
# 19647           FUT2            2524         64.34        101.54
#
#        TCGA-22-5478  TCGA-22-5472  TCGA-43-5670  TCGA-60-2709  TCGA-22-5489  \
# 0             33.06         35.50         73.03         60.39         92.05
# 1            119.26        169.07        165.57        161.02        131.51
# 2            412.00        743.43       1340.84        607.87       1709.26
# 3             40.93         67.12         54.72         29.27         20.26
# 4            108.14        109.66        190.34        211.31         96.01
# ...             ...           ...           ...           ...           ...
# 19641         83.45        232.94        167.90         80.01        161.02
# 19642       5831.91       5329.30       5711.87       6164.49       8134.41
# 19643        660.68        620.67        518.15        848.22        366.09
# 19646          0.99          3.59          2.23          3.35          0.00
# 19647         14.45         69.52        110.43         36.53         60.82
#
#        TCGA-77-8007  TCGA-22-5471  TCGA-22-4609  TCGA-22-5482  TCGA-56-8082  \
# 0             66.65         54.33         15.56         55.49         30.34
# 1            198.47        175.07        147.06        151.22         84.63
# 2           1709.26        603.67        555.41        693.58        616.37
# 3             23.76         28.04         39.22         46.50         42.41
# 4            208.38        120.10        239.52        124.37        249.73
# ...             ...           ...           ...           ...           ...
# 19641        104.42         81.14        113.56        220.32         81.71
# 19642       6516.03       8598.28       5633.22       5219.60       4937.99
# 19643       1073.91        363.56        366.09        397.93        497.00
# 19646          7.34          1.41          0.00          2.63          0.00
# 19647        116.78         66.18         25.54         80.01         17.00
#
#        TCGA-22-5483  TCGA-56-8623  TCGA-33-4587  TCGA-56-7579  TCGA-43-3394  \
# 0             14.45        100.83        131.51         59.55         87.03
# 1             72.01        248.00        363.56        218.79        173.85
# 2            518.15        813.63        753.83        769.69        642.59
# 3             37.85         51.35         24.81         53.95         35.00
# 4            103.69        214.27        162.14        195.72        127.89
# ...             ...           ...           ...           ...           ...
# 19641         85.22        108.14        136.19         88.88        112.77
# 19642       6792.79       6792.79       7857.29       6983.79       5672.41
# 19643        791.35        503.95        547.75        470.14        507.46
# 19646          1.00          3.03          0.00          2.97          0.57
# 19647         18.56        115.97         42.71         42.71        100.13
#
#        TCGA-34-8454  TCGA-77-7338  TCGA-43-6143  TCGA-43-6773  TCGA-51-4080  \
# 0             71.50         23.08         48.87         72.52        115.97
# 1            253.23        120.10        131.51        110.43        205.50
# 2            624.99        854.13        802.41       1037.29        532.74
# 3             54.72         53.95         19.25         34.51         51.71
# 4            127.00        119.26        124.37        180.02        115.16
# ...             ...           ...           ...           ...           ...
# 19641        325.29        228.13        305.55        285.03        204.07
# 19642       5517.27       6079.61       6294.04       3690.52       5517.27
# 19643        368.65        320.80        540.19        808.00        656.11
# 19646          1.00          0.00          1.07          7.69          2.97
# 19647         16.39         43.94         71.50         66.18         85.22
#
#        TCGA-34-7107  TCGA-39-5040  TCGA-43-6771  TCGA-92-7340  TCGA-77-7138  \
# 0             45.21         74.58          8.92         27.44         40.64
# 1            162.14        363.56        120.10         85.22        214.27
# 2           1088.92        842.36        507.46        769.69        514.56
# 3             12.64         25.35         43.32         64.34         43.63
# 4            105.89        334.46        199.85        208.38        195.72
# ...             ...           ...           ...           ...           ...
# 19641        307.69         74.58        114.36        149.12        139.07
# 19642       3665.02       6037.61       4512.40       5366.37       6887.62
# 19643        693.58        412.00        698.41        406.31        397.93
# 19646          3.50          0.54          0.97          0.96          0.00
# 19647         43.63         18.84         14.45         42.41         42.71
#
#        TCGA-77-7142  TCGA-56-7823  TCGA-22-5491  TCGA-22-5481  TCGA-90-7767  \
# 0             35.76         59.13         20.86         37.05         48.18
# 1            126.12        138.10        214.27        170.25        112.77
# 2            974.50       1340.84        679.29        444.72        928.30
# 3             77.25         40.93         33.30         33.30         58.71
# 4            202.66        214.27        132.44        114.36        176.29
# ...             ...           ...           ...           ...           ...
# 19641        150.17        229.72        197.09        127.00        231.32
# 19642       5633.22       5255.91       7966.99       7695.57       6607.01
# 19643        420.68        703.28        185.11        414.87        438.59
# 19646          1.83          1.75          0.56          0.00          1.75
# 19647         11.47         63.89         60.39         88.88         28.65
#
#        TCGA-77-8008  TCGA-56-7730  TCGA-33-6737  TCGA-56-7582  TCGA-56-7731  \
# 0             51.71         49.56         72.01         21.94         27.44
# 1            111.21        180.02        197.09        111.21         93.35
# 2           1233.75        718.08       1051.79       2367.90        389.72
# 3             29.27         32.59         44.89         55.49         24.11
# 4            195.72        105.89        111.21        228.13        130.60
# ...             ...           ...           ...           ...           ...
# 19641        155.50         59.13        253.23        287.01         23.42
# 19642       4512.40       9540.50       4298.64       5791.62       5594.30
# 19643        551.56        287.01        341.51        373.81        473.41
# 19646          3.35          4.31          0.00          4.13          2.61
# 19647         84.63         69.03         31.45         32.13         70.51
#
#        TCGA-77-7337  TCGA-43-7658  TCGA-56-8201  TCGA-85-7710  TCGA-56-7580  \
# 0             35.00         76.17         28.86         90.77         59.55
# 1            114.36        231.32        181.28        185.11        119.26
# 2            836.53        669.92        460.44        813.63       2400.97
# 3             56.28         39.79         38.40         34.51         70.01
# 4            165.57        159.90        202.66        251.48        209.84
# ...             ...           ...           ...           ...           ...
# 19641        185.11         62.12         69.03        145.02        202.66
# 19642       6164.49       9540.50       6745.86       3955.48       4869.99
# 19643        525.39        480.04        450.94        559.28        579.04
# 19646          2.66          0.55          1.45          6.94          1.00
# 19647          8.78         84.04         36.01         38.12         17.64
#
#        TCGA-43-6647  TCGA-90-6837  TCGA-56-8083  TCGA-51-4079  TCGA-56-7222  \
# 0             40.07         22.92         29.91         82.29          4.70
# 1            102.97        123.50        264.03        194.36        166.73
# 2            543.96       2193.99        540.19        521.76        253.23
# 3             57.49         57.89         67.12         34.51         22.10
# 4            120.10        109.66        155.50        162.14        277.20
# ...             ...           ...           ...           ...           ...
# 19641        111.99        371.22        154.42        289.02         32.59
# 19642       6935.54       4836.35       7230.10       6250.56       6840.04
# 19643        420.68        366.09        334.46        258.57        329.84
# 19646          0.00          4.58          0.96          3.06          1.83
# 19647         14.56         14.35          5.77         24.28         21.78
#
#        TCGA-22-4593  TCGA-51-4081  TCGA-56-8309
# 0             37.32         43.63         77.25
# 1            105.15        185.11        356.05
# 2            764.36        518.15        878.17
# 3             31.90         28.24         49.91
# 4             86.43        164.42        155.50
# ...             ...           ...           ...
# 19641        191.67        204.07         88.26
# 19642       5292.48       3928.15       7130.55
# 19643       1030.12        665.29        633.73
# 19646          1.77          3.63          2.56
# 19647         16.27         73.54         88.26
#
# [17275 rows x 52 columns]

# %%
cancer2.to_csv("data/cancer2.csv")

# %%
cancer2
# Out:
#          Hugo_Symbol  Entrez_Gene_Id  TCGA-43-7657  TCGA-58-8386  \
# 0           HIST3H2A           92815        336.79        500.46
# 1              LIN7B           64130        105.15        212.78
# 2                LXN           56925        848.22        236.21
# 3             CNKSR2           22866         32.59          8.51
# 4              SCML1            6322         84.63         74.58
# ...              ...             ...           ...           ...
# 19641         ZNF521           25925         37.32         76.71
# 19642         SPINT2           10653      56265.94       3901.01
# 19643         HAVCR2           84868         74.58        432.53
# 19646  CTD-2116N17.1               0          6.89         10.79
# 19647           FUT2            2524        105.15         58.30
#
#        TCGA-22-5478  TCGA-22-5472  TCGA-43-5670  TCGA-60-2709  TCGA-22-5489  \
# 0            703.28        287.01        486.75         70.51        145.02
# 1            102.25        212.78        172.65        244.57        105.89
# 2            271.48        759.08         61.25        620.67        329.84
# 3             45.85          6.16         49.21         11.91         12.27
# 4             67.12         57.89        102.97        132.44         66.65
# ...             ...           ...           ...           ...           ...
# 19641         59.97         84.04         14.24        202.66        435.55
# 19642      16843.62      12244.81      37901.36       8479.89       9606.86
# 19643        128.79        208.38         13.93        633.73        348.71
# 19646          8.51          6.84          9.13          9.93         14.78
# 19647         39.79       1059.11        366.09         97.36         46.50
#
#        TCGA-77-8007  TCGA-22-5471  TCGA-22-4609  TCGA-22-5482  TCGA-56-8082  \
# 0             14.03        397.93        318.57        463.65          6.78
# 1            152.28        258.57        218.79        249.73        199.85
# 2            599.49        587.13        638.15        400.71         99.43
# 3             15.00          1.38          8.71          4.31         10.31
# 4             57.08        336.79        171.45         94.67         31.67
# ...             ...           ...           ...           ...           ...
# 19641         59.55         30.56         69.03         49.91         39.79
# 19642      10959.30      20881.40       8134.41       9945.68       5872.48
# 19643        420.68        283.05        432.53         72.01         49.21
# 19646         15.56          8.13          0.97          9.27         14.56
# 19647        101.54        336.79        414.87        262.20        143.01
#
#        TCGA-22-5483  TCGA-56-8623  TCGA-33-4587  TCGA-56-7579  TCGA-43-3394  \
# 0            242.88        135.24        363.56        231.32        403.50
# 1            215.77        215.77         62.56        231.32        173.85
# 2            287.01        896.64        100.13        143.01        830.75
# 3              9.20         35.00         26.86         16.88         25.72
# 4            134.30        206.94        118.43        205.50        202.66
# ...             ...           ...           ...           ...           ...
# 19641        198.47         86.43         14.24         37.32         41.81
# 19642       7642.41       6887.62      11827.67      11035.54      23009.42
# 19643        226.54        555.41         80.57        148.09        150.17
# 19646         27.25          0.00          7.28          5.06         15.91
# 19647        136.19        147.06        140.04        480.04        141.02
#
#        TCGA-34-8454  TCGA-77-7338  TCGA-43-6143  TCGA-43-6773  TCGA-51-4080  \
# 0            136.19        130.60        285.03        156.59        954.43
# 1            164.42         81.71        217.27        323.03        373.81
# 2            603.67        708.18        490.14        555.41        688.78
# 3              2.73          8.71         25.54          4.54         23.76
# 4            191.67        110.43        131.51         62.12        220.32
# ...             ...           ...           ...           ...           ...
# 19641         81.71         64.80         63.89        116.78         11.04
# 19642       9409.14       9876.98      14361.31       3018.30       7180.15
# 19643        223.41        170.25        102.25        283.05        100.13
# 19646          5.23          7.17         27.25          5.19         17.77
# 19647        275.28        339.14         28.86         77.79        131.51
#
#        TCGA-34-7107  TCGA-39-5040  TCGA-43-6771  TCGA-92-7340  TCGA-77-7138  \
# 0            454.09        110.43         16.51        447.82        103.69
# 1            136.19        231.32        153.34        177.53        181.28
# 2            463.65        246.28         81.14        860.08        107.38
# 3              6.41         18.70          0.00          2.89          2.03
# 4            224.97         38.95         84.63        161.02        182.55
# ...             ...           ...           ...           ...           ...
# 19641         99.43         20.41         69.03        145.02         21.94
# 19642       9808.75      19082.00       9740.98      12160.22      17317.18
# 19643        170.25         92.05        137.14        241.19         70.51
# 19646         16.15          1.28         13.42          5.87          8.78
# 19647         84.04         28.24        988.12        339.14        323.03
#
#        TCGA-77-7142  TCGA-56-7823  TCGA-22-5491  TCGA-22-5481  TCGA-90-7767  \
# 0            187.71        127.89        718.08        836.53         98.73
# 1             49.91        181.28        435.55        162.14         87.03
# 2            353.59        358.54        285.03         88.26        412.00
# 3              9.56          3.59          8.85         21.78         15.91
# 4             56.28        129.69        417.77         68.55        147.06
# ...             ...           ...           ...           ...           ...
# 19641         47.17          9.48         12.83         57.49        264.03
# 19642      12076.21       9673.69      12415.75      27174.14       7032.37
# 19643        180.02         49.56        101.54        131.51        181.28
# 19646          6.52         28.86          9.78          0.00         13.22
# 19647        140.04        438.59        351.14         48.52         97.36
#
#        TCGA-77-8008  TCGA-56-7730  TCGA-33-6737  TCGA-56-7582  TCGA-56-7731  \
# 0             80.57        260.38        197.09        223.41        343.89
# 1            199.85        305.55        165.57        162.14        171.45
# 2            607.87        579.04        414.87        490.14        684.02
# 3              1.73         74.58          6.52         25.35          7.17
# 4             77.79        206.94         61.68        267.73         74.58
# ...             ...           ...           ...           ...           ...
# 19641        206.94          5.63         58.30         19.39         50.63
# 19642      18052.61       8840.04      13399.51       7130.55      18178.19
# 19643        293.07         31.45        153.34        215.77        231.32
# 19646          8.78         17.77          9.56         23.08          8.00
# 19647        343.89        131.51        167.90        353.59        595.34
#
#        TCGA-77-7337  TCGA-43-7658  TCGA-56-8201  TCGA-85-7710  TCGA-56-7580  \
# 0            303.44        115.16         74.06          3.06        420.68
# 1             80.57        215.77        106.63        135.24        135.24
# 2            571.05        121.79        339.14        688.78        204.07
# 3              2.76         13.12          4.31          1.38          6.62
# 4             96.01        361.04        170.25        165.57        119.26
# ...             ...           ...           ...           ...           ...
# 19641        102.97         30.34         51.71         22.59         33.78
# 19642      12244.81       7180.15       7433.40      18052.61      15392.14
# 19643        145.02        291.04        651.58        150.17         57.49
# 19646          2.71          3.14          7.46          8.85          6.21
# 19647        163.28         40.93         77.25        106.63         35.50
#
#        TCGA-43-6647  TCGA-90-6837  TCGA-56-8083  TCGA-51-4079  TCGA-56-7222  \
# 0            109.66        106.63       1233.75        172.65        303.44
# 1            151.22        395.18        295.11        120.94        114.36
# 2            438.59        503.95       3039.30        607.87        106.63
# 3              6.11          1.66         33.54          3.11          0.82
# 4             87.65         53.57        232.94         67.12         64.80
# ...             ...           ...           ...           ...           ...
# 19641        148.09        106.63        297.17         22.26         25.72
# 19642      20030.74      20593.91       9808.75      11189.60      10733.74
# 19643        236.21        353.59         29.48        202.66         33.78
# 19646          4.94         17.64         28.65         14.78         27.64
# 19647         55.49        738.29        232.94        244.57         71.50
#
#        TCGA-22-4593  TCGA-51-4081  TCGA-56-8309
# 0            228.13        251.48         23.59
# 1             96.68        277.20        153.34
# 2            507.46        255.00        346.29
# 3              3.32         27.25          6.16
# 4             90.14        198.47        154.42
# ...             ...           ...           ...
# 19641        106.63         71.00         37.05
# 19642      10014.87       6983.79      23169.48
# 19643         73.54         55.89        480.04
# 19646         15.80         31.00          4.86
# 19647         53.57        332.14         69.52
#
# [17275 rows x 52 columns]

# %%
#for independent
accp_i=[] #accepted probability list
accpgenes_i=[] #rejected probability genes list
rep_i=[] #accepted probability list
repgenes_i=[]  #rejected probability genes list

#for paired
accp_r=[] #accepted probability list
accpgenes_r=[] #accepted probability genes list
rep_r=[] #rejected probability list
repgenes_r=[]  #rejected probability genes list

p_values_r=[] # propability list for paired
p_values_i=[]  # propability list for independent

# %%
#Assume confidence level=95%, alpha=0.05
for m in range(len(healthy2)):
    G_h = healthy2.iloc[m, 2:] # piking gene no. m from healthy set
    G_c = cancer2.iloc[m, 2:] # piking gene no. m from cancer set

    p_val_r = ttest_rel(G_h, G_c).pvalue #paired
    p_values_r.append(p_val_r)  # propability list while paired

    if p_val_r >= 0.05:  #accept H0 as p > 0.05   # for paired
        accp_r.append(p_val_r)
        accpgenes_r.append(healthy2.iloc[m, 0]) 

    else:   #rejection region --> reject H0  
        rep_r.append(p_val_r)
        repgenes_r.append(healthy2.iloc[m, 0])

    p_val_i = ttest_ind(G_h, G_c).pvalue #independent
    p_values_i.append(p_val_i)  # propability list while independent

    if p_val_i >= 0.05:  #accept H0 as p > 0.05  #for independent 
        accp_i.append(p_val_i)
        accpgenes_i.append(healthy2.iloc[m, 0])

    else:   #rejection region --> reject H0  
        rep_i.append(p_val_i)
        repgenes_i.append(healthy2.iloc[m, 0])

# %%
'There are '+str (len(accp_i))+' accepted genes as independent'
# Out:
# 'There are 4675 accepted genes as independent'

# %%
accpgenes_i
# Out:
# ['LIN7B',
#  'AC024592.12',
#  'VPS52',
#  'AEN',
#  'VWA1',
#  'EXOSC9',
#  'RPS15A',
#  'SFMBT1',
#  'S100P',
#  'RDH14',
#  'ACOT8',
#  'NFKBIB',
#  'NENF',
#  'NTRK1',
#  'CCDC62',
#  'NOXRED1',
#  'JOSD2',
#  'CDH10',
#  'PTX3',
#  'MEP1B',
#  'COL4A2',
#  'FBXO42',
#  'NBEAL1',
#  'VPS13B',
#  'ZMYM3',
#  'SEMA3D',
#  'RBM44',
#  'C14orf119',
#  'REV1',
#  'ECH1',
#  'LRRC24',
#  'C1orf109',
#  'APOBEC3G',
#  'IQCH',
#  'CD180',
#  'RP11-849F2.7',
#  'CTNNA3',
#  'CCL3L1',
#  'ANKRD33B',
#  'BHMT2',
#  'ZNF2',
#  'SPCS2',
#  'RAB42',
#  'ACP6',
#  'ANKRD20A4',
#  'CES1',
#  'TBL1Y',
#  'IL17REL',
#  'KIAA0895',
#  'TLR10',
#  'ELP3',
#  'SLC38A11',
#  'RRH',
#  'ALDOB',
#  'ADIPOR2',
#  'DLGAP1',
#  'PTPN2',
#  'PPDPF',
#  'FABP7',
#  'CBR4',
#  'CNPY3',
#  'RELT',
#  'TSTD2',
#  'EPS8L3',
#  'RPS6KL1',
#  'KCNQ4',
#  'THAP9',
#  'TSR2',
#  'AL136218.1',
#  'CHST10',
#  'IP6K3',
#  'NODAL',
#  'SLC6A9',
#  'ZNF17',
#  'GPR35',
#  'C20orf112',
#  'EXOC3L4',
#  'CLEC11A',
#  'INO80E',
#  'ZNF232',
#  'SLC12A3',
#  'NAP1L2',
#  'ZNF440',
#  'C1D',
#  'GFER',
#  'SGSM3',
#  'TMEM26',
#  'TOMM40L',
#  'SLC30A1',
#  'AGXT',
#  'ESM1',
#  'HRH2',
#  'CIDEB',
#  'ITFG2',
#  'DLL1',
#  'PDDC1',
#  'APLP1',
#  'TNFRSF11B',
#  'NDUFV2',
#  'PLAC8L1',
#  'WDR91',
#  'FAM26F',
#  'TMEM242',
#  'ANXA1',
#  'KIAA0922',
#  'UTS2B',
#  'GDPD3',
#  'HELZ2',
#  'SLC12A7',
#  'HOOK3',
#  'DEFB4A',
#  'S100A1',
#  'MX2',
#  'DDX59',
#  'CELF4',
#  'ARCN1',
#  'ILKAP',
#  'KLHL26',
#  'DIO3',
#  'AC115618.1',
#  'PCP4L1',
#  'SMCHD1',
#  'CRLF3',
#  'ZFP14',
#  'VPS41',
#  'SLC25A41',
#  'FAM153A',
#  'PIP5K1A',
#  'ZNF257',
#  'OPCML',
#  'RPS20',
#  'ZBED6',
#  'ZNF71',
#  'MINOS1',
#  'DPP9',
#  'AC023590.1',
#  'PLA2G7',
#  'ZNF503',
#  'ZMIZ2',
#  'C1orf43',
#  'LAMTOR4',
#  'NPIPA8',
#  'SYNE4',
#  'CAMKK1',
#  'ERC1',
#  'FAM163B',
#  'RGS8',
#  'SLC6A3',
#  'SYT3',
#  'PEX3',
#  'NPL',
#  'ZFX',
#  'DNAJB1',
#  'TRIP11',
#  'ZNF516',
#  'MID2',
#  'ZNF177',
#  'C16orf58',
#  'PSENEN',
#  'FLJ27365',
#  'CDH26',
#  'S1PR3',
#  'ISLR',
#  'MT1F',
#  'RAB39A',
#  'ZNF568',
#  'LCN2',
#  'PNOC',
#  'CYP7B1',
#  'PPM1A',
#  'CTC-435M10.3',
#  'GRAMD4',
#  'TPCN2',
#  'OTUD7A',
#  'INHBA',
#  'C22orf26',
#  'GRM3',
#  'ELL',
#  'USP50',
#  'BMF',
#  'OTOF',
#  'C19orf60',
#  'AVIL',
#  'HNRNPUL2',
#  'PRIMPOL',
#  'PBX1',
#  'ANKRD50',
#  'IFT52',
#  'PLEKHA7',
#  'POU5F2',
#  'FLNC',
#  'CCM2',
#  'DOHH',
#  'TNNT3',
#  'WBP1',
#  'ZNF780B',
#  'UBE2Q2',
#  'SPIRE2',
#  'CENPB',
#  'ZDHHC23',
#  'PCMT1',
#  'ELP5',
#  'ALOX15',
#  'COG6',
#  'RASGRF2',
#  'MTRNR2L4',
#  'C17orf51',
#  'POC1B-GALNT4',
#  'EIF3L',
#  'NUDT17',
#  'DRG2',
#  'PRH2',
#  'AANAT',
#  'FAM117A',
#  'CLDN3',
#  'ADC',
#  'LAYN',
#  'FASTKD5',
#  'CLEC5A',
#  'NUP98',
#  'ACOX1',
#  'CXorf31',
#  'FAM96A',
#  'FCHSD1',
#  'MMS19',
#  'GPLD1',
#  'SLITRK3',
#  'CCDC93',
#  'L3HYPDH',
#  'SP5',
#  'EPHA2',
#  'VAC14',
#  'SP7',
#  'ACOX3',
#  'MXI1',
#  'ALS2',
#  'BFSP2',
#  'LRRC4',
#  'AC010536.1',
#  'DDX6',
#  'CLTB',
#  'C10orf137',
#  'HEY2',
#  'TSC22D4',
#  'PRL',
#  'HGD',
#  'KIF5C',
#  'C2CD5',
#  'BGLAP',
#  'CBLN2',
#  'RBM39',
#  'PEX5',
#  'TRIP4',
#  'EIF2B3',
#  'DACT1',
#  'CMTR1',
#  'NEDD8-MDP1',
#  'PCDHA4',
#  'PRRG2',
#  'RP11-276H1.3',
#  'ZNF223',
#  'GRID2IP',
#  'SERPINB8',
#  'IP6K2',
#  'INPP5F',
#  'REEP1',
#  'IFIH1',
#  'CREBZF',
#  'FCRL5',
#  'PLCB4',
#  'CTC-236F12.4',
#  'RPS6',
#  'RP11-565P22.6',
#  'DOC2A',
#  'MTHFD2L',
#  'KLF3',
#  'PDE10A',
#  'AL353354.2',
#  'LYRM7',
#  'IGSF9B',
#  'SCNN1D',
#  'SESN2',
#  'UTS2',
#  'A1BG',
#  'MOK',
#  'HOXB9',
#  'WNT8B',
#  'GLTSCR1',
#  'SIGLEC10',
#  'DCTD',
#  'MEAF6',
#  'BUD13',
#  'DOT1L',
#  'FAM211B',
#  'IFRG15',
#  'TTC23',
#  'MT1G',
#  'C8orf47',
#  'CDH11',
#  'ZNF221',
#  'ARSG',
#  'IRF7',
#  'RNF169',
#  'MUS81',
#  'RLN1',
#  'CCDC97',
#  'PRKAA1',
#  'C16orf80',
#  'KCTD20',
#  'PSCA',
#  'RANBP17',
#  'ATG12',
#  'C4orf36',
#  'UGT2B15',
#  'SLC12A6',
#  'TRAPPC6A',
#  'ZNF853',
#  'SPATA12',
#  'LMTK3',
#  'C17orf82',
#  'SPIN4',
#  'HAVCR1',
#  'RPS12',
#  'ADAMTS5',
#  'FOXP2',
#  'PRKRIR',
#  'HDDC3',
#  'ECE1',
#  'CDC20B',
#  'SLC22A1',
#  'ABCB8',
#  'KIRREL3',
#  'GPR31',
#  'RSPO3',
#  'DAAM1',
#  'BCL2L14',
#  'MLLT10',
#  'CORT',
#  'RBM33',
#  'CCNT2',
#  'DYNLRB1',
#  'INTU',
#  'PPOX',
#  'C6orf58',
#  'CCDC122',
#  'BACH2',
#  'TBC1D19',
#  'UBBP4',
#  'VPS33B',
#  'CRAT',
#  'C17orf47',
#  'RIMKLB',
#  'L3MBTL3',
#  'P2RX6',
#  'AASDH',
#  'TOR2A',
#  'UNC5B',
#  'PI4KA',
#  'C12orf79',
#  'RP11-190A12.7',
#  'ASCL1',
#  'AP3S2',
#  'TRIM66',
#  'CASC3',
#  'CSNK1G3',
#  'RP11-139J15.7',
#  'CTD-2192J16.20',
#  'GCM1',
#  'TCP10L',
#  'DEDD2',
#  'MAP2K1',
#  'COX11',
#  'ENSA',
#  'DPP10',
#  'FAM27A',
#  'SYT8',
#  'MGST1',
#  'NOV',
#  'FMO4',
#  'FAM131B',
#  'CHRNE',
#  'SRSF4',
#  'FAM19A2',
#  'PDGFRA',
#  'AC005841.1',
#  'AKAP1',
#  'GCK',
#  'TTC3',
#  'KAAG1',
#  'SUPT6H',
#  'ZNF397',
#  'C2orf76',
#  'ASNA1',
#  'FDXACB1',
#  'RIMBP3B',
#  'TULP1',
#  'ZNF268',
#  'CHCHD5',
#  'CDH16',
#  'TMOD4',
#  'VAMP4',
#  'UGT2B17',
#  'NRG1',
#  'LRRN2',
#  'HADHB',
#  'HAPLN1',
#  'FCRL2',
#  'GATAD1',
#  'USF2',
#  'ORAI2',
#  'C1QTNF9B',
#  'TRAPPC8',
#  'DLGAP2',
#  'PINLYP',
#  'UGCG',
#  'PCDH11X',
#  'AMBRA1',
#  'GNE',
#  'EML4',
#  'ZSCAN31',
#  'ASPDH',
#  'ASS1',
#  'RICTOR',
#  'LRRD1',
#  'FAM205A',
#  'ZNF341',
#  'MBD3',
#  'HIATL1',
#  'PIWIL4',
#  'ARHGAP1',
#  'NPIPB7',
#  'ADAMTS16',
#  'SLC2A10',
#  'LYPD5',
#  'C7orf26',
#  'MXRA7',
#  'KIAA1161',
#  'SRSF11',
#  'CPLX1',
#  'NOX1',
#  'STAMBPL1',
#  'MAGT1',
#  'B4GALT5',
#  'ZC3H12D',
#  'IRX6',
#  'SSBP3',
#  'ADAMTS7',
#  'PRSS16',
#  'EEF1B2',
#  'ACSS1',
#  'P2RY4',
#  'GLCE',
#  'PPFIA1',
#  'PRRT1',
#  'TYK2',
#  'AGAP7',
#  'GPR45',
#  'PPCS',
#  'DUSP10',
#  'PAX5',
#  'HEXIM1',
#  'PLXNA4',
#  'SLC25A44',
#  'SLC18A1',
#  'JAKMIP2',
#  'C20orf197',
#  'DXO',
#  'CDC42EP4',
#  'AL035252.1',
#  'JMJD6',
#  'RNF181',
#  'FRMPD3',
#  'C6orf48',
#  'SEZ6',
#  'SEC61B',
#  'ZNF610',
#  'CALCB',
#  'CCRN4L',
#  'FSTL1',
#  'RPAIN',
#  'POU2F3',
#  'COX17',
#  'FOSL1',
#  'MAP2K7',
#  'GIGYF1',
#  'RAMP1',
#  'BCMO1',
#  'LUC7L2',
#  'KRT18',
#  'MME',
#  'MAEL',
#  'AMD1',
#  'ZNF614',
#  'SSBP3-AS1',
#  'MRPL34',
#  'GRM8',
#  'IGBP1',
#  'D2HGDH',
#  'TESK1',
#  'ZNF878',
#  'PEX12',
#  'ARHGAP22',
#  'DAG1',
#  'MED9',
#  'FAAH2',
#  'CAPN6',
#  'MRPL33',
#  'SGPP2',
#  'LIMD2',
#  'AC027228.1',
#  'TRIB2',
#  'UBL5',
#  'EIF4G2',
#  'LRRC37B',
#  'IGFBP6',
#  'CCL11',
#  'WDR31',
#  'IFI6',
#  'EIF2AK3',
#  'RAB9B',
#  'CCDC25',
#  'FRS2',
#  'UEVLD',
#  'AC021860.1',
#  'SLC35G2',
#  'PHF3',
#  'TAOK1',
#  'C11orf57',
#  'ELMOD3',
#  'TXLNG',
#  'WBSCR27',
#  'CCDC116',
#  'TCF12',
#  'ANGPTL2',
#  'LRBA',
#  'ZBTB3',
#  'CDV3',
#  'LRRC37A',
#  'THAP5',
#  'GNAO1',
#  'LAIR2',
#  'SSUH2',
#  'PTRH1',
#  'ZNF410',
#  'OXR1',
#  'ZBTB2',
#  'SNX32',
#  'PRDM4',
#  'CCDC74B',
#  'RHBDD1',
#  'RP11-297N6.4',
#  'ZNF571',
#  'LSM10',
#  'IL37',
#  'ERN2',
#  'HMSD',
#  'RP11-468E2.4',
#  'PDZRN4',
#  'FBN1',
#  'MTMR12',
#  'CLDN6',
#  'TFAP2B',
#  'SMOC2',
#  'MGST2',
#  'IRF4',
#  'TRNAU1AP',
#  'NCKIPSD',
#  'CFHR1',
#  'GSTM1',
#  'QRFP',
#  'CNR2',
#  'INTS10',
#  'VAMP1',
#  'STOX1',
#  'CHAD',
#  'PLEKHA6',
#  'COMMD1',
#  'PPP2R4',
#  'BLNK',
#  'PSAPL1',
#  'GOLGA6A',
#  'TULP2',
#  'IRGM',
#  'PACS2',
#  'UPK2',
#  'ZNF625',
#  'IFI44L',
#  'RP11-268J15.5',
#  'ZFC3H1',
#  'ZNF579',
#  'CTTNBP2',
#  'UQCRQ',
#  'MRP63',
#  'PCDHA5',
#  'AC006132.1',
#  'ACER2',
#  'SPIN2B',
#  'DFNB59',
#  'CASC10',
#  'SPINK6',
#  'IKBKB',
#  'SPIB',
#  'FAM216A',
#  'TMEM120B',
#  'PKIA',
#  'NXPE2',
#  'LRIT3',
#  'LPAR4',
#  'SDCCAG8',
#  'SH2B2',
#  'DHPS',
#  'OS9',
#  'NPIPA7',
#  'AC010441.1',
#  'PITPNM1',
#  'CYP4F22',
#  'EEPD1',
#  'DPYSL3',
#  'GCNT2',
#  'TBC1D1',
#  'DMWD',
#  'GULP1',
#  'ZBP1',
#  'SERF2',
#  'BPIFB2',
#  'ZNF33A',
#  'PTEN',
#  'ATP6V0E2',
#  'HECA',
#  'GMEB1',
#  'NPTN',
#  'SDS',
#  'CIDEC',
#  'PWWP2B',
#  'MORC3',
#  'CCND2',
#  'CHST4',
#  'CHD5',
#  'C8orf31',
#  'FOCAD',
#  'ETV7',
#  'ZKSCAN2',
#  'CAMK2D',
#  'AC135048.1',
#  'METTL15',
#  'LPAR1',
#  'KLK6',
#  'RMDN1',
#  'AC006538.4',
#  'RAB35',
#  'RBFOX3',
#  'STXBP5',
#  'OTUD3',
#  'ZNF791',
#  'PDLIM7',
#  'SRFBP1',
#  'STXBP4',
#  'KDM2A',
#  'ZSCAN12',
#  'NHLH2',
#  'R3HDML',
#  'ZNF285',
#  'AMFR',
#  'NT5C3A',
#  'C1QL2',
#  'CACUL1',
#  'NECAP1',
#  'GSTA1',
#  'ZSCAN32',
#  'ZNF140',
#  'NKX2-8',
#  'FAM127C',
#  'SEPSECS',
#  'ZHX1',
#  'TSKS',
#  'USP6NL',
#  'C20orf196',
#  'ACER3',
#  'MSMB',
#  'RPL27',
#  'AL031663.2',
#  'MMP8',
#  'KCNA1',
#  'USP43',
#  'SLC38A5',
#  'C15orf38-AP3S2',
#  'RDH12',
#  'PUM1',
#  'HTR3E',
#  'ANGPTL4',
#  'ZNF428',
#  'PEX5L',
#  'TDGF1',
#  'RGS1',
#  'VNN1',
#  'ARFGAP2',
#  'AC069368.3',
#  'C1orf50',
#  'OSBPL10',
#  'BRD8',
#  'C21orf59',
#  'FOXC2',
#  'CHRNA6',
#  'RP11-598P20.5',
#  'ZNF264',
#  'NXN',
#  'LCORL',
#  'CSTF2T',
#  'IMPA1',
#  'RANBP9',
#  'FKBP6',
#  'IRS4',
#  'SLC2A14',
#  'CHCHD4',
#  'UVSSA',
#  'DLGAP4',
#  'NUTM2G',
#  'IDO2',
#  'ZNF785',
#  'EBF3',
#  'ADCK1',
#  'NYNRIN',
#  'OBP2A',
#  'UBL7',
#  'APPBP2',
#  'C21orf58',
#  'COQ2',
#  'GPR18',
#  'RRNAD1',
#  'LRP6',
#  'PSTPIP1',
#  'CYP2C9',
#  'CDKN1B',
#  'ZNF644',
#  'ATF7IP2',
#  'PYROXD1',
#  'BAMBI',
#  'TFPI2',
#  'CRAMP1L',
#  'PPP6C',
#  'AL132989.1',
#  'TMED8',
#  'POMP',
#  'PRRT3',
#  'TMTC1',
#  'ZNF281',
#  'SAMD15',
#  'MED4',
#  'ZNF391',
#  'ZNF595',
#  'HFE',
#  'TMEM251',
#  'ADCY1',
#  'MICB',
#  'LMF2',
#  'FCER2',
#  'FRMPD1',
#  'NLRP6',
#  'TTC13',
#  'SEC24A',
#  'PLBD2',
#  'RPP38',
#  'CNTN2',
#  'HKR1',
#  'CXXC4',
#  'RFNG',
#  'C1orf61',
#  'WDR73',
#  'ZNF773',
#  'SGK2',
#  'USP11',
#  'MYL2',
#  'USP18',
#  'RNF113A',
#  'C1orf53',
#  'KRTAP5-2',
#  'IMPG2',
#  'FAM134A',
#  'PCDHB2',
#  'ENPP6',
#  'CACNG8',
#  'CCT6B',
#  'NOG',
#  'SELT',
#  'NEIL2',
#  'ATP6V1F',
#  'RNF31',
#  'RPL13',
#  'NPTX2',
#  'HKDC1',
#  'GOLGA2',
#  'CAMK1G',
#  'QPCT',
#  'KCNA2',
#  'IGFN1',
#  'KSR1',
#  'TOR1AIP2',
#  'CYFIP1',
#  'ZBTB17',
#  'IFT43',
#  'COPRS',
#  'RP11-286N22.8',
#  'RHOXF1',
#  'RFC1',
#  'HINT1',
#  'BOC',
#  'AL133373.1',
#  'ENDOU',
#  'NOS1',
#  'CYP3A43',
#  'DZIP1L',
#  'KIAA0319',
#  'CYP1B1',
#  'FAM196A',
#  'CAMSAP2',
#  'TUBA8',
#  'FAM168A',
#  'OPA3',
#  'TSLP',
#  'CXCL11',
#  'LRFN2',
#  'RAD50',
#  'VLDLR',
#  'CASP16',
#  'RP11-542C16.2',
#  'TNFSF9',
#  'PCDHB16',
#  'SLC35C1',
#  'DNPEP',
#  'BAG2',
#  'RAP2C',
#  'HMGN5',
#  'BCAS3',
#  'RNF135',
#  'RNF170',
#  'AP000695.1',
#  'PLK2',
#  'STIM2',
#  'DNAJC25-GNG10',
#  'CTNNBL1',
#  'PDZD8',
#  'PTPN7',
#  'SMARCC2',
#  'TNFRSF17',
#  'TSPAN1',
#  'SUSD3',
#  'MET',
#  'EDEM3',
#  'PTMS',
#  'MRPL46',
#  'CCDC112',
#  'RWDD2B',
#  'HSD17B2',
#  'AGFG1',
#  'BSN',
#  'SLC8A2',
#  'LYPLAL1',
#  'GDPGP1',
#  'GRAMD1B',
#  'WEE2',
#  'PCBP3',
#  'SRRM1',
#  'DBNL',
#  'PELI3',
#  'ENC1',
#  'ZFR2',
#  'ZNF575',
#  'MTRNR2L8',
#  'MAFB',
#  'DTX1',
#  'USP6',
#  'MRFAP1L1',
#  'RAB12',
#  'NDUFB7',
#  'C1QTNF1-AS1',
#  'HAPLN2',
#  'MDM4',
#  'RPL15',
#  'SLC5A5',
#  'ELOVL3',
#  'TUB',
#  'DVL1',
#  'C11orf42',
#  'SAMD8',
#  'PCDHGB2',
#  'NHLH1',
#  'PENK',
#  'HCRTR1',
#  'METTL10',
#  'COL2A1',
#  'GPR150',
#  'ZNF394',
#  'AL592284.1',
#  'HGSNAT',
#  'SNCA',
#  'CYB5B',
#  'IRF2BP2',
#  'FAM150A',
#  'PGBD2',
#  'MYO1H',
#  'CXCR5',
#  'ASB13',
#  'C19orf54',
#  'GRIA3',
#  'CNOT4',
#  'NDRG4',
#  'DHDDS',
#  'TIFAB',
#  'KRT40',
#  'RP11-178L8.4',
#  'VTI1B',
#  'LAMTOR5',
#  'GPR25',
#  'DNASE2',
#  'ZNF461',
#  'MATN4',
#  'PDE9A',
#  'EPS8',
#  'CXorf40A',
#  'SEC62',
#  'TNKS',
#  'CDCP2',
#  'ZSCAN5A',
#  'LTN1',
#  'TNKS1BP1',
#  'C3orf80',
#  'IBA57',
#  'ZCCHC18',
#  'RP11-210M15.2',
#  'SSTR2',
#  'TEP1',
#  'PCDHB13',
#  'RNF25',
#  'LAMB1',
#  'SLC9A5',
#  'TGM1',
#  'RPL23',
#  'INHBB',
#  'RPL37A',
#  'RPS24',
#  'MIF4GD',
#  'AC011551.3',
#  'NPIPA3',
#  'MFGE8',
#  'ZNF460',
#  'HESX1',
#  'KIAA1432',
#  'ZNF789',
#  'ZADH2',
#  'DEF8',
#  'CHMP4A',
#  'ARL5C',
#  'KCNJ13',
#  'FAM153B',
#  'TAB1',
#  'TERF2',
#  'SPDYE2',
#  'AKAP3',
#  'FAM221A',
#  'ZNF775',
#  'BEAN1',
#  'NBPF14',
#  'RIMBP3',
#  'PDPN',
#  'ALKBH1',
#  'C14orf93',
#  'SLTM',
#  'LUC7L3',
#  'ADRBK1',
#  'RHOBTB3',
#  'CD99',
#  'PAK4',
#  'MRPL49',
#  'UNC79',
#  'OPN1SW',
#  'RBM14-RBM4',
#  'ZNF552',
#  'GSDMA',
#  'C16orf52',
#  'RP11-41O4.1',
#  'CXorf58',
#  'SRA1',
#  'PRSS36',
#  'LRRC17',
#  'ZNF117',
#  'RP11-343C2.11',
#  'SP4',
#  'BTG4',
#  'CPA5',
#  'NIPSNAP3B',
#  'SLC25A19',
#  'LDLRAP1',
#  'SNX7',
#  'SAMD11',
#  'CTSA',
#  'NSMAF',
#  'FAM212A',
#  'ACSL6',
#  'PTPN20A',
#  'NIPAL2',
#  ...]

# %%
'There are '+str (len(rep_i))+' rejected genes as independent'
# Out:
# 'There are 12600 rejected genes as independent'

# %%
repgenes_i
# Out:
# ['HIST3H2A',
#  'LXN',
#  'CNKSR2',
#  'SCML1',
#  'GSDMD',
#  'AKR1C1',
#  'C3orf62',
#  'CRISPLD2',
#  'DOCK5',
#  'SLC33A1',
#  'GLI1',
#  'STK17B',
#  'RP5-966M1.6',
#  'HAGHL',
#  'CDC37L1',
#  'KRT10',
#  'CYHR1',
#  'TNFAIP8L2',
#  'PFDN2',
#  'TCP1',
#  'ALG9',
#  'PMEL',
#  'CYBA',
#  'GINS1',
#  'GPX3',
#  'IPO9',
#  'SHKBP1',
#  'ARHGAP40',
#  'ENO3',
#  'COX19',
#  'LMF1',
#  'GDE1',
#  'LSM14B',
#  'TLE2',
#  'EIF4EBP3',
#  'LRP2BP',
#  'PELO',
#  'CDIPT',
#  'C19orf44',
#  'PABPN1',
#  'ZWINT',
#  'DYNLL1',
#  'NRXN3',
#  'FYTTD1',
#  'CAPRIN1',
#  'AOC3',
#  'KIFC3',
#  'DOCK11',
#  'TMEM231',
#  'DNAH17',
#  'DCHS1',
#  'ZFYVE19',
#  'HS3ST4',
#  'SLC5A8',
#  'WDR53',
#  'NLN',
#  'TBC1D31',
#  'ZNF597',
#  'RNF114',
#  'SFRP2',
#  'PNMA2',
#  'HENMT1',
#  'STX16',
#  'BFAR',
#  'SHROOM3',
#  'NUP107',
#  'HS6ST1',
#  'BRWD3',
#  'FGF11',
#  'CCDC138',
#  'FAM193B',
#  'BATF',
#  'AGFG2',
#  'TVP23B',
#  'BCL6',
#  'DNAJC3',
#  'C1orf233',
#  'ADH6',
#  'ITGB6',
#  'CEACAM21',
#  'ETV6',
#  'C1RL',
#  'CCDC181',
#  'GPN3',
#  'RAP1GAP',
#  'MAGED2',
#  'C1orf85',
#  'JRKL',
#  'BHLHE40',
#  'NMUR1',
#  'SPATA18',
#  'NTPCR',
#  'CBWD3',
#  'TLDC2',
#  'GNAI2',
#  'MNDA',
#  'RP11-347C12.3',
#  'CLEC6A',
#  'FCGR2A',
#  'ZNF491',
#  'SEP15',
#  'GMFG',
#  'MAGEH1',
#  'GMFB',
#  'AC068987.1',
#  'SLC7A2',
#  'FAM83G',
#  'CCNA2',
#  'PSMC1',
#  'TGIF1',
#  'C18orf21',
#  'TDRKH',
#  'TXNDC15',
#  'IPO5',
#  'C8B',
#  'DGKD',
#  'TMPO',
#  'LY86',
#  'LDOC1',
#  'MAD2L1',
#  'BAI1',
#  'TOMM70A',
#  'MRI1',
#  'ARAP1',
#  'DZIP1',
#  'VDAC3',
#  'RBM42',
#  'MROH7-TTC4',
#  'ATP8B2',
#  'MMADHC',
#  'SIK3',
#  'GOLIM4',
#  'FLJ20306',
#  'TSHZ2',
#  'ADAM11',
#  'SNX18',
#  'KIF17',
#  'PARP11',
#  'IL7',
#  'RBPMS2',
#  'AGTR2',
#  'PLA2G4D',
#  'MTDH',
#  'MT-CYB',
#  'TRIP6',
#  'CYSLTR1',
#  'SH3BGRL',
#  'TAF15',
#  'NMU',
#  'AC079354.1',
#  'NPIPA1',
#  'DNAJA3',
#  'TIAF1',
#  'KAT5',
#  'CPNE9',
#  'CHORDC1',
#  'IL26',
#  'RIOK1',
#  'HIBCH',
#  'OGFOD1',
#  'CSNK1G2',
#  'GNA14',
#  'CCDC68',
#  'ZNF564',
#  'ANKRD6',
#  'NDUFS3',
#  'EFCAB4B',
#  'STRN',
#  'SCARF2',
#  'C5orf22',
#  'FBXO45',
#  'TOP2B',
#  'ZNF16',
#  'CYP2F1',
#  'AMIGO1',
#  'STX16-NPEPL1',
#  'ESPN',
#  'LAPTM4A',
#  'KCNK3',
#  'PDE2A',
#  'TTLL11',
#  'FBXO38',
#  'ANKMY1',
#  'GTF2IRD1',
#  'BIRC6',
#  'EIF1AY',
#  'SEC22A',
#  'ZC3H15',
#  'DHCR24',
#  'ZDHHC2',
#  'C1orf220',
#  'GLG1',
#  'DKKL1',
#  'AK3',
#  'HEATR2',
#  'PRKX',
#  'PARD6A',
#  'ANKRD18B',
#  'GKN2',
#  'FAM89B',
#  'RABL2B',
#  'PFN4',
#  'HDAC2',
#  'TMEM182',
#  'ARNT',
#  'CHDH',
#  'PRRG4',
#  'UVRAG',
#  'C16orf96',
#  'SMIM8',
#  'MFAP5',
#  'DYNC2H1',
#  'C17orf53',
#  'IST1',
#  'SLC39A10',
#  'ZNF675',
#  'MAPK1',
#  'RIMBP2',
#  'BUB1B',
#  'GABRR1',
#  'LCAT',
#  'AKR1C3',
#  'DAPK3',
#  'ZP2',
#  'SETDB1',
#  'GRIA2',
#  'AEBP2',
#  'ABTB2',
#  'RP11-77K12.7',
#  'IL20RB',
#  'UBQLN4',
#  'ZFYVE9',
#  'AGPAT4',
#  'PSME1',
#  'SCAMP1',
#  'TRAM2',
#  'PPP2R1B',
#  'ATG5',
#  'H2AFV',
#  'KARS',
#  'ANKRD2',
#  'NFIB',
#  'SRC',
#  'EIF4EBP2',
#  'EPHA7',
#  'BANK1',
#  'RNASEL',
#  'FAM84A',
#  'CEP128',
#  'RPP21',
#  'CCDC104',
#  'SLC4A7',
#  'SFMBT2',
#  'IGSF1',
#  'FAM189B',
#  'SLC36A1',
#  'CHI3L2',
#  'TMEM8A',
#  'DPYSL2',
#  'FNDC1',
#  'LGALS2',
#  'ZNF354A',
#  'FAM179B',
#  'SPAG4',
#  'C3orf58',
#  'ABT1',
#  'TNC',
#  'ARNTL',
#  'KCTD15',
#  'CARD11',
#  'POGLUT1',
#  'ETS2',
#  'SIVA1',
#  'C8orf4',
#  'CXADR',
#  'MIB1',
#  'ELOVL6',
#  'ADAMTS10',
#  'RHOF',
#  'MOSPD2',
#  'AMN1',
#  'SELENBP1',
#  'RSPH9',
#  'PIGU',
#  'PRELID1',
#  'ZNF649',
#  'NOSTRIN',
#  'XKR8',
#  'RCC1',
#  'CERK',
#  'MANF',
#  'IFNAR1',
#  'EMC4',
#  'ABCA6',
#  'RAB7L1',
#  'CDKN1C',
#  'C15orf54',
#  'C19orf59',
#  'AKAP11',
#  'NMRK1',
#  'MRPS5',
#  'CAMP',
#  'SMARCD2',
#  'SMARCAL1',
#  'SLC39A12',
#  'CD1E',
#  'ACR',
#  'SYCE3',
#  'C12orf49',
#  'PLEKHA5',
#  'PRMT8',
#  'SLC35D2',
#  'MCAM',
#  'EIF2B1',
#  'LRRC8C',
#  'IRF8',
#  'CKLF',
#  'FANCB',
#  'SPP1',
#  'CERS5',
#  'MKI67',
#  'IRAK1',
#  'MGARP',
#  'IL2RA',
#  'MARCH3',
#  'CD55',
#  'TMEM63C',
#  'SSSCA1',
#  'ATF3',
#  'TDRD12',
#  'CDH15',
#  'NDUFA12',
#  'MARK4',
#  'KIAA1107',
#  'TSFM',
#  'TBC1D23',
#  'DHFR',
#  'MAPK10',
#  'CNIH3',
#  'PTP4A3',
#  'MBTPS2',
#  'PUS1',
#  'DDX27',
#  'B3GNT1',
#  'C4A',
#  'C17orf103',
#  'PIK3R4',
#  'NOMO3',
#  'EIF4A2',
#  'BMPR2',
#  'AC090186.1',
#  'RNF32',
#  'SMIM13',
#  'NIPAL4',
#  'EPHX4',
#  'LNX2',
#  'CTD-2583A14.10',
#  'GADL1',
#  'ACAT2',
#  'ULBP3',
#  'AGPAT3',
#  'ABCC1',
#  'CHCHD2',
#  'ANO5',
#  'RALBP1',
#  'HERPUD2',
#  'ZNF596',
#  'NFU1',
#  'MRPL54',
#  'DMXL1',
#  'ZBTB8A',
#  'NFXL1',
#  'CTU2',
#  'NPDC1',
#  'PPP3R1',
#  'FAT2',
#  'AMMECR1L',
#  'ZFHX2',
#  'RSRC1',
#  'UBE2J1',
#  'PSMA5',
#  'CXorf56',
#  'RRP15',
#  'IL32',
#  'RAD51D',
#  'KLF17',
#  'C18orf54',
#  'RPUSD4',
#  'MRPS7',
#  'PRRC2B',
#  'LGR4',
#  'ANO7',
#  'CCDC107',
#  'C10orf112',
#  'NMBR',
#  'GPATCH8',
#  'MRPS31',
#  'NLGN3',
#  'TNFSF13',
#  'RPS17',
#  'HSDL2',
#  'PSPN',
#  'NKX6-1',
#  'ST3GAL2',
#  'TBC1D4',
#  'ADAR',
#  'MTPN',
#  'RHBDD3',
#  'MTR',
#  'CHRM2',
#  'LAMTOR3',
#  'RPS10-NUDT3',
#  'LSMEM1',
#  'TULP4',
#  'LENG8',
#  'PFDN4',
#  'LPAR2',
#  'MRPS16',
#  'CASP3',
#  'ARSA',
#  'FAM102B',
#  'ENPP2',
#  'RHBDF2',
#  'VTN',
#  'KIF5B',
#  'SNN',
#  'ST6GALNAC5',
#  'PSMB7',
#  'UBE2H',
#  'ASB11',
#  'PHF6',
#  'NUDCD1',
#  'CAPZA2',
#  'ARHGAP29',
#  'AGTR1',
#  'FAM72C',
#  'WDR66',
#  'RCAN2',
#  'CLEC4E',
#  'NTN3',
#  'SEPN1',
#  'GDF1',
#  'ST14',
#  'CIAPIN1',
#  'RBMS3',
#  'EIF3E',
#  'SDAD1',
#  'ACVRL1',
#  'PLB1',
#  'MAP3K4',
#  'HIST1H2BL',
#  'TARS2',
#  'PUS7',
#  'ZNF132',
#  'DPF1',
#  'RMI2',
#  'ZNRD1',
#  'IGSF10',
#  'PCDHGA9',
#  'ANKRD7',
#  'MTCH2',
#  'FOSB',
#  'KCNJ14',
#  'JPH2',
#  'CRIP2',
#  'PALMD',
#  'GINM1',
#  'APOBEC3C',
#  'CYP24A1',
#  'IGFALS',
#  'CCT4',
#  'BEND7',
#  'CXorf36',
#  'LRRC46',
#  'RPL35A',
#  'C5orf55',
#  'NPRL3',
#  'FOXA2',
#  'MSI2',
#  'RPL21',
#  'TRUB2',
#  'EVC',
#  'CEP57L1',
#  'ENTPD1',
#  'EXOSC2',
#  'UTP6',
#  'SH3YL1',
#  'SORBS1',
#  'MTMR2',
#  'NOC2L',
#  'MT-ND1',
#  'MAP3K7',
#  'VWA3A',
#  'STEAP1',
#  'PIK3C2A',
#  'DNM2',
#  'CYTH1',
#  'FAM195B',
#  'RNF8',
#  'ALMS1',
#  'TRIQK',
#  'SLC25A3',
#  'P2RX4',
#  'NKX3-2',
#  'ACTN1',
#  'C15orf61',
#  'CD80',
#  'ACTR1A',
#  'TRNP1',
#  'C9orf66',
#  'VAV3',
#  'PGLYRP1',
#  'ANKRD54',
#  'NEK7',
#  'RNF4',
#  'ASB6',
#  'CX3CR1',
#  'AIMP2',
#  'KCNQ1',
#  'C19orf52',
#  'CCSER2',
#  'LITAF',
#  'NTF3',
#  'SLC43A3',
#  'CNGA4',
#  'OXGR1',
#  'DDX39B',
#  'ZNF436',
#  'FH',
#  'ICAM3',
#  'MSANTD1',
#  'DRD2',
#  'DGKA',
#  'PFDN5',
#  'PLBD1',
#  'TNFAIP1',
#  'CCR4',
#  'CHRAC1',
#  'LRRN1',
#  'OSBPL1A',
#  'ZNF695',
#  'PDCL',
#  'P2RY12',
#  'KHDRBS1',
#  'KRT6A',
#  'CCDC91',
#  'SMTNL2',
#  'GINS4',
#  'BMP7',
#  'CPQ',
#  'MRPL30',
#  'CXCL3',
#  'TMEM66',
#  'TACC2',
#  'C2orf49',
#  'RSU1',
#  'SCAND3',
#  'EXOSC6',
#  'UBE2F',
#  'LRRC4B',
#  'TGM4',
#  'RASSF5',
#  'PPP3CA',
#  'APOL6',
#  'KANSL3',
#  'DAPK1',
#  'LAMA5',
#  'GJB6',
#  'FAM155B',
#  'PTPRF',
#  'ATP1A3',
#  'TUBGCP3',
#  'USP31',
#  'RASEF',
#  'PLA2G10',
#  'FAM181B',
#  'C3orf49',
#  'SPATS2L',
#  'AHI1',
#  'CXCL12',
#  'CHGA',
#  'LDHC',
#  'HPX',
#  'LINC00908',
#  'EMG1',
#  'GPR89C',
#  'LPL',
#  'IL12RB1',
#  'EZR',
#  'LSR',
#  'TM7SF3',
#  'PCDH17',
#  'POLR3K',
#  'CPVL',
#  'MMP7',
#  'WDR74',
#  'ZP3',
#  'KBTBD3',
#  'SWI5',
#  'C7orf31',
#  'GRWD1',
#  'FAM81B',
#  'EMP2',
#  'MAT1A',
#  'HPDL',
#  'FBXO8',
#  'PARP16',
#  'ST6GALNAC4',
#  'CLEC3B',
#  'LRRC29',
#  'HMMR',
#  'CYP2W1',
#  'FBXO43',
#  'PLEKHH2',
#  'FXYD3',
#  'FCER1A',
#  'NCK1',
#  'DSN1',
#  'CD247',
#  'MLANA',
#  'RAB37',
#  'THUMPD2',
#  'HVCN1',
#  'LMX1B',
#  'SFTPA1',
#  'CA8',
#  'RPL38',
#  'RNF215',
#  'STAR',
#  'SLC16A11',
#  'PLEKHN1',
#  'KIF18A',
#  'IL17RC',
#  'RC3H1',
#  'PTDSS1',
#  'TMEM115',
#  'QDPR',
#  'FITM1',
#  'FABP4',
#  'ZNF514',
#  'MMP17',
#  'MLH1',
#  'SPRY3',
#  'VRK1',
#  'ORM2',
#  'C16orf46',
#  'ZNF717',
#  'FAM13B',
#  'POLR3C',
#  'FMNL1',
#  'MGST3',
#  'DDX41',
#  'ZXDB',
#  'C3orf35',
#  'SH3PXD2A',
#  'MAGEF1',
#  'NOB1',
#  'TSC22D1',
#  'CELF5',
#  'NUTF2',
#  'LRRC69',
#  'SMARCC1',
#  'DCUN1D4',
#  'C10orf118',
#  'ZBTB45',
#  'RGL4',
#  'C9orf172',
#  'SLC12A5',
#  'C9orf116',
#  'CDKN2AIP',
#  'CTNND2',
#  'RBKS',
#  'B4GALT2',
#  'LRRC2',
#  'GAA',
#  'LHX6',
#  'DSC1',
#  'MEA1',
#  'SLC46A2',
#  'C6orf201',
#  'ZHX1-C8ORF76',
#  'ZNF33B',
#  'HSD17B12',
#  'CACNA2D3',
#  'PDSS1',
#  'MYCL',
#  'ITIH5',
#  'PLTP',
#  'RAB41',
#  'FBN2',
#  'TCN1',
#  'WSCD1',
#  'MCF2L2',
#  'MSANTD2',
#  'GPT',
#  'RASA4B',
#  'TAF7L',
#  'YTHDC2',
#  'SLC25A45',
#  'TLE6',
#  'GAL3ST4',
#  'GNMT',
#  'CLEC7A',
#  'FAM177A1',
#  'SND1',
#  'TNK1',
#  'RP11-830F9.6',
#  'PDE1B',
#  'BYSL',
#  'SPTBN5',
#  'ZNF273',
#  'MAP1LC3B2',
#  'RAB11FIP3',
#  'MAST4',
#  'TBC1D17',
#  'CYYR1',
#  'PLEKHB2',
#  'KIAA1462',
#  'SGK3',
#  'C11orf52',
#  'EIF6',
#  'EPC1',
#  'DIS3',
#  'NELFE',
#  'TSKU',
#  'AOC2',
#  'TTC39C',
#  'SLC29A3',
#  'MVB12B',
#  'FUT11',
#  'VPS51',
#  'PKP1',
#  'PPP1R14A',
#  'CDKN2A',
#  'MCM8',
#  'HSPA9',
#  'DNAJB11',
#  'PRKDC',
#  'MLF1IP',
#  'UNC119',
#  'FGF18',
#  'NRBP1',
#  'CRYL1',
#  'KRT6B',
#  'PLEKHS1',
#  'METAP1',
#  'TMEM80',
#  'SAPCD2',
#  'A2ML1',
#  'LEPR',
#  'PDGFRB',
#  'HIST1H4J',
#  'USH2A',
#  'EXOC8',
#  'CTB-133G6.1',
#  'SYNPO2L',
#  'RALGPS1',
#  'MED24',
#  'STRADB',
#  'C12orf54',
#  'ACSL3',
#  'ZNF215',
#  'MSRB3',
#  'QSOX2',
#  'PCCA',
#  'FOXRED1',
#  'SLC26A5',
#  'ITPR1',
#  'ZHX3',
#  'DUT',
#  'SSTR1',
#  'RDH16',
#  'PPP1R9A',
#  'MORC4',
#  'PI4K2A',
#  'PCDHA7',
#  'RMI1',
#  'SLC27A3',
#  'PGGT1B',
#  'TSC22D3',
#  'PHF11',
#  'MPLKIP',
#  'HN1',
#  'OMD',
#  'ATAD3C',
#  'ZNF736',
#  'PDE4DIP',
#  'SIGIRR',
#  'ZNF594',
#  'C1orf173',
#  'MBNL1',
#  'PIBF1',
#  'STX2',
#  'MRPS30',
#  'LIMS3L',
#  'GYPC',
#  'PROS1',
#  'PSKH1',
#  'TSPYL1',
#  'ERGIC1',
#  'TSPAN13',
#  'GPR146',
#  'ATE1',
#  'MOBP',
#  'GPC2',
#  'H2AFY2',
#  'GLCCI1',
#  'NARF',
#  'BTBD8',
#  'SPATA5L1',
#  'MPHOSPH8',
#  'PPP1R2',
#  'TAF10',
#  'RAD1',
#  'PDSS2',
#  'MAP4',
#  'LDHD',
#  'RASAL1',
#  'C5orf56',
#  'FBXL2',
#  'MPDZ',
#  'GALE',
#  'GOSR2',
#  'CENPL',
#  'C21orf128',
#  'DHX57',
#  'VMP1',
#  'KDR',
#  'FAM111B',
#  'NME1',
#  'STK25',
#  'SERTM1',
#  'SPRR2E',
#  'KCNQ5',
#  'MLIP',
#  'PGS1',
#  'MARCH1',
#  'KCNH1',
#  'IVNS1ABP',
#  'WDR83OS',
#  'TCIRG1',
#  'NLE1',
#  'TIGD7',
#  'LYN',
#  'MYOM3',
#  'C1orf123',
#  'RASSF8',
#  'MBOAT7',
#  'NGLY1',
#  'ST8SIA4',
#  'TBC1D12',
#  'DNAJC11',
#  'VOPP1',
#  'PBDC1',
#  'GLTPD1',
#  'FILIP1L',
#  'SKA2',
#  'GZMB',
#  'WDR11',
#  'MYPOP',
#  'PDCD2L',
#  'ITSN2',
#  'FAXDC2',
#  'PIGX',
#  'ANKHD1-EIF4EBP3',
#  'NACAD',
#  'PCSK2',
#  'GGA3',
#  'DNAJC13',
#  'SLC25A37',
#  'GPX1',
#  'PHEX',
#  'DUSP26',
#  'ILF2',
#  'LYPD3',
#  'UBR3',
#  'RPS6KC1',
#  'TENC1',
#  'LGALS9',
#  'FAM19A3',
#  'PDIA3',
#  'C9orf16',
#  'HOMER2',
#  'GID8',
#  'AC062017.1',
#  'ZBBX',
#  'BRPF1',
#  'CCR5',
#  'ZNF44',
#  'FBXO27',
#  'C17orf89',
#  'MAGEA2',
#  'GNL3L',
#  'ALDH3A1',
#  'FAS',
#  'CSPP1',
#  'NDNF',
#  'PARN',
#  'DECR2',
#  'SMAD9',
#  'TOP1MT',
#  'LENG1',
#  'POLR3F',
#  'MYCN',
#  'VAMP3',
#  'XKR6',
#  'PPBP',
#  'CLK3',
#  'ERMAP',
#  'CDR1',
#  'STXBP6',
#  'NR2C2AP',
#  'C2orf54',
#  'PBLD',
#  'PURB',
#  'IKZF1',
#  'MED22',
#  'ODC1',
#  'ISG20',
#  'STYXL1',
#  'FAM105A',
#  'ABCB5',
#  'FAM86A',
#  'CD81',
#  'TMX4',
#  'NFKBID',
#  'REEP2',
#  'RNPS1',
#  'IYD',
#  'BAIAP2',
#  'FEZF1',
#  'ROBO2',
#  'CCNC',
#  'C17orf99',
#  'ARRDC1',
#  'MFNG',
#  'PNPLA6',
#  'DMRTA1',
#  'WDR54',
#  'RP2',
#  'STIL',
#  'FREM1',
#  'DBF4',
#  'ZNF418',
#  'MESDC2',
#  'AARD',
#  'ZNF626',
#  'PPWD1',
#  'ZC2HC1C',
#  'C16orf93',
#  'CD33',
#  'BLVRB',
#  'CLDND2',
#  'MBNL3',
#  'IER3IP1',
#  'RAD21',
#  'TMED5',
#  'TXNDC9',
#  'LMAN2L',
#  'RNFT2',
#  'ART1',
#  'FERMT3',
#  'DUSP8',
#  'CTPS1',
#  'GADD45G',
#  'SYTL2',
#  'HSPA14',
#  'TH',
#  'ABCF2',
#  'SZT2',
#  'PPP1R3C',
#  'PLCH2',
#  'EQTN',
#  'CUL2',
#  'DNAH11',
#  'ARMCX3',
#  'SLC25A18',
#  'TEC',
#  'MATN3',
#  'KLHL12',
#  'GPRIN1',
#  'THOP1',
#  'TMEM178A',
#  'ADRA2B',
#  'SUPV3L1',
#  'PPP1R13L',
#  'CABLES2',
#  'SEC61G',
#  'PSMB5',
#  'LIN7C',
#  'PARP14',
#  'EPS8L2',
#  'WIPI2',
#  'KLRD1',
#  'NOLC1',
#  'GCHFR',
#  'SPRTN',
#  'MYLIP',
#  'C16orf71',
#  'PNO1',
#  ...]

# %%
'There are '+str (len(accp_r))+' accepted genes as paired'
# Out:
# 'There are 4582 accepted genes as paired'

# %%
accpgenes_r
# Out:
# ['LIN7B',
#  'SCML1',
#  'AC024592.12',
#  'DOCK5',
#  'VPS52',
#  'AEN',
#  'VWA1',
#  'EXOSC9',
#  'RPS15A',
#  'SFMBT1',
#  'S100P',
#  'ACOT8',
#  'NFKBIB',
#  'NENF',
#  'NTRK1',
#  'CCDC62',
#  'NOXRED1',
#  'JOSD2',
#  'CDH10',
#  'PTX3',
#  'MEP1B',
#  'COL4A2',
#  'FBXO42',
#  'NBEAL1',
#  'VPS13B',
#  'ZMYM3',
#  'SEMA3D',
#  'RBM44',
#  'C14orf119',
#  'REV1',
#  'ECH1',
#  'LRRC24',
#  'C1orf109',
#  'APOBEC3G',
#  'IQCH',
#  'CD180',
#  'RP11-849F2.7',
#  'CTNNA3',
#  'CCL3L1',
#  'ANKRD33B',
#  'BHMT2',
#  'ZNF2',
#  'SPCS2',
#  'PARP11',
#  'RAB42',
#  'ACP6',
#  'ANKRD20A4',
#  'CES1',
#  'TBL1Y',
#  'IL17REL',
#  'KIAA0895',
#  'TLR10',
#  'SLC38A11',
#  'RRH',
#  'ALDOB',
#  'ADIPOR2',
#  'DLGAP1',
#  'PTPN2',
#  'FABP7',
#  'CBR4',
#  'CNPY3',
#  'RELT',
#  'TSTD2',
#  'EPS8L3',
#  'RPS6KL1',
#  'KCNQ4',
#  'MFAP5',
#  'THAP9',
#  'TSR2',
#  'AL136218.1',
#  'CHST10',
#  'IP6K3',
#  'NODAL',
#  'SLC6A9',
#  'ZNF17',
#  'GPR35',
#  'C20orf112',
#  'EXOC3L4',
#  'INO80E',
#  'ZNF232',
#  'SLC12A3',
#  'NAP1L2',
#  'ZNF440',
#  'C1D',
#  'GFER',
#  'SGSM3',
#  'TMEM26',
#  'TOMM40L',
#  'SLC30A1',
#  'AGXT',
#  'ESM1',
#  'HRH2',
#  'CIDEB',
#  'ITFG2',
#  'DLL1',
#  'PDDC1',
#  'APLP1',
#  'TNFRSF11B',
#  'NDUFV2',
#  'WDR91',
#  'FAM26F',
#  'TMEM242',
#  'ANXA1',
#  'KIAA0922',
#  'UTS2B',
#  'GDPD3',
#  'HELZ2',
#  'SLC12A7',
#  'HOOK3',
#  'DEFB4A',
#  'S100A1',
#  'MX2',
#  'DDX59',
#  'CELF4',
#  'ARCN1',
#  'ILKAP',
#  'KLHL26',
#  'DIO3',
#  'AC115618.1',
#  'PCP4L1',
#  'SMCHD1',
#  'CRLF3',
#  'ZFP14',
#  'VPS41',
#  'SLC25A41',
#  'FAM153A',
#  'PIP5K1A',
#  'ZNF257',
#  'OPCML',
#  'RPS20',
#  'ZBED6',
#  'ZNF71',
#  'MINOS1',
#  'DPP9',
#  'AC023590.1',
#  'PLA2G7',
#  'ZNF503',
#  'ZMIZ2',
#  'C1orf43',
#  'LAMTOR4',
#  'SYNE4',
#  'CAMKK1',
#  'ERC1',
#  'FAM163B',
#  'RGS8',
#  'SLC6A3',
#  'SYT3',
#  'PEX3',
#  'NPL',
#  'ZFX',
#  'DNAJB1',
#  'TRIP11',
#  'ZNF516',
#  'MID2',
#  'ZNF177',
#  'C16orf58',
#  'PSENEN',
#  'FLJ27365',
#  'CDH26',
#  'S1PR3',
#  'ISLR',
#  'MT1F',
#  'RAB39A',
#  'ZNF568',
#  'LCN2',
#  'PNOC',
#  'CYP7B1',
#  'PPM1A',
#  'CTC-435M10.3',
#  'GRAMD4',
#  'TPCN2',
#  'OTUD7A',
#  'INHBA',
#  'GRM3',
#  'ELL',
#  'USP50',
#  'BMF',
#  'OTOF',
#  'C19orf60',
#  'AVIL',
#  'HNRNPUL2',
#  'PRIMPOL',
#  'PBX1',
#  'ANKRD50',
#  'IFT52',
#  'PLEKHA7',
#  'POU5F2',
#  'FLNC',
#  'TNNT3',
#  'WBP1',
#  'ZNF780B',
#  'UBE2Q2',
#  'SPIRE2',
#  'CENPB',
#  'ZDHHC23',
#  'PCMT1',
#  'ALOX15',
#  'COG6',
#  'RASGRF2',
#  'MTRNR2L4',
#  'C17orf51',
#  'POC1B-GALNT4',
#  'EIF3L',
#  'NUDT17',
#  'DRG2',
#  'PRH2',
#  'AANAT',
#  'FAM117A',
#  'CLDN3',
#  'ADC',
#  'LAYN',
#  'FASTKD5',
#  'CLEC5A',
#  'NUP98',
#  'ACOX1',
#  'CXorf31',
#  'FAM96A',
#  'FCHSD1',
#  'MMS19',
#  'GPLD1',
#  'SLITRK3',
#  'CCDC93',
#  'SP5',
#  'EPHA2',
#  'VAC14',
#  'SP7',
#  'ACOX3',
#  'MXI1',
#  'ALS2',
#  'BFSP2',
#  'LRRC4',
#  'AC010536.1',
#  'DDX6',
#  'CLTB',
#  'C10orf137',
#  'HEY2',
#  'TSC22D4',
#  'PRL',
#  'HGD',
#  'KIF5C',
#  'C2CD5',
#  'BGLAP',
#  'CBLN2',
#  'RBM39',
#  'PEX5',
#  'TRIP4',
#  'EIF2B3',
#  'DACT1',
#  'CMTR1',
#  'NEDD8-MDP1',
#  'PCDHA4',
#  'PRRG2',
#  'RP11-276H1.3',
#  'ZNF223',
#  'GRID2IP',
#  'SERPINB8',
#  'INPP5F',
#  'REEP1',
#  'IFIH1',
#  'CREBZF',
#  'FCRL5',
#  'PLCB4',
#  'CTC-236F12.4',
#  'MOBP',
#  'RPS6',
#  'RP11-565P22.6',
#  'DOC2A',
#  'MTHFD2L',
#  'KLF3',
#  'PDE10A',
#  'AL353354.2',
#  'LYRM7',
#  'IGSF9B',
#  'SCNN1D',
#  'SESN2',
#  'UTS2',
#  'A1BG',
#  'MOK',
#  'HOXB9',
#  'WNT8B',
#  'GLTSCR1',
#  'SIGLEC10',
#  'DCTD',
#  'MEAF6',
#  'BUD13',
#  'DOT1L',
#  'FAM211B',
#  'IFRG15',
#  'TTC23',
#  'MT1G',
#  'C8orf47',
#  'CDH11',
#  'ZNF221',
#  'ARSG',
#  'IRF7',
#  'RNF169',
#  'MUS81',
#  'RLN1',
#  'CCDC97',
#  'PRKAA1',
#  'C16orf80',
#  'PSCA',
#  'RANBP17',
#  'ATG12',
#  'C4orf36',
#  'UGT2B15',
#  'SLC12A6',
#  'ZNF853',
#  'SPATA12',
#  'LMTK3',
#  'C17orf82',
#  'SPIN4',
#  'HAVCR1',
#  'RPS12',
#  'ADAMTS5',
#  'FOXP2',
#  'PRKRIR',
#  'HDDC3',
#  'ECE1',
#  'CDC20B',
#  'SLC22A1',
#  'ABCB8',
#  'KIRREL3',
#  'GPR31',
#  'RSPO3',
#  'MBNL3',
#  'DAAM1',
#  'BCL2L14',
#  'MLLT10',
#  'CORT',
#  'RBM33',
#  'CCNT2',
#  'DYNLRB1',
#  'INTU',
#  'PPOX',
#  'C6orf58',
#  'CCDC122',
#  'BACH2',
#  'TBC1D19',
#  'UBBP4',
#  'VPS33B',
#  'CRAT',
#  'C17orf47',
#  'RIMKLB',
#  'L3MBTL3',
#  'P2RX6',
#  'AASDH',
#  'TOR2A',
#  'UNC5B',
#  'PI4KA',
#  'C12orf79',
#  'RP11-190A12.7',
#  'ASCL1',
#  'TRIM66',
#  'CASC3',
#  'CSNK1G3',
#  'RP11-139J15.7',
#  'CTD-2192J16.20',
#  'GCM1',
#  'TCP10L',
#  'DEDD2',
#  'MAP2K1',
#  'COX11',
#  'ENSA',
#  'DPP10',
#  'FAM27A',
#  'SYT8',
#  'MGST1',
#  'NOV',
#  'FMO4',
#  'FAM131B',
#  'CHRNE',
#  'SRSF4',
#  'FAM19A2',
#  'PDGFRA',
#  'AC005841.1',
#  'AKAP1',
#  'GCK',
#  'TTC3',
#  'KAAG1',
#  'SUPT6H',
#  'ZNF397',
#  'C2orf76',
#  'ASNA1',
#  'FDXACB1',
#  'RIMBP3B',
#  'TULP1',
#  'ZNF268',
#  'CHCHD5',
#  'CDH16',
#  'TMOD4',
#  'VAMP4',
#  'UGT2B17',
#  'NRG1',
#  'LRRN2',
#  'HADHB',
#  'HAPLN1',
#  'FCRL2',
#  'GATAD1',
#  'USF2',
#  'ORAI2',
#  'C1QTNF9B',
#  'TRAPPC8',
#  'DLGAP2',
#  'PINLYP',
#  'UGCG',
#  'PCDH11X',
#  'AMBRA1',
#  'GNE',
#  'EML4',
#  'ZSCAN31',
#  'ASPDH',
#  'ASS1',
#  'RICTOR',
#  'LRRD1',
#  'FAM205A',
#  'ZNF341',
#  'MBD3',
#  'HIATL1',
#  'PIWIL4',
#  'ARHGAP1',
#  'NPIPB7',
#  'ADAMTS16',
#  'SLC2A10',
#  'LYPD5',
#  'C7orf26',
#  'MXRA7',
#  'KIAA1161',
#  'SRSF11',
#  'CPLX1',
#  'NOX1',
#  'STAMBPL1',
#  'MAGT1',
#  'B4GALT5',
#  'ZC3H12D',
#  'IRX6',
#  'SSBP3',
#  'ADAMTS7',
#  'PRSS16',
#  'EEF1B2',
#  'ACSS1',
#  'P2RY4',
#  'GLCE',
#  'PPFIA1',
#  'PRRT1',
#  'TYK2',
#  'AGAP7',
#  'GPR45',
#  'PPCS',
#  'DUSP10',
#  'PAX5',
#  'HEXIM1',
#  'PLXNA4',
#  'SLC25A44',
#  'SLC18A1',
#  'JAKMIP2',
#  'C20orf197',
#  'DXO',
#  'CDC42EP4',
#  'JMJD6',
#  'RNF181',
#  'FRMPD3',
#  'C6orf48',
#  'SEZ6',
#  'SEC61B',
#  'CALCB',
#  'CCRN4L',
#  'FSTL1',
#  'RPAIN',
#  'POU2F3',
#  'COX17',
#  'FOSL1',
#  'MAP2K7',
#  'GIGYF1',
#  'RAMP1',
#  'BCMO1',
#  'LUC7L2',
#  'KRT18',
#  'MME',
#  'MAEL',
#  'AMD1',
#  'HLA-DOB',
#  'ZNF614',
#  'SSBP3-AS1',
#  'MRPL34',
#  'GRM8',
#  'IGBP1',
#  'D2HGDH',
#  'TESK1',
#  'ZNF878',
#  'PEX12',
#  'ARHGAP22',
#  'DAG1',
#  'MED9',
#  'FAAH2',
#  'CAPN6',
#  'MRPL33',
#  'SGPP2',
#  'LIMD2',
#  'AC027228.1',
#  'TRIB2',
#  'UBL5',
#  'EIF4G2',
#  'LRRC37B',
#  'IGFBP6',
#  'CCL11',
#  'WDR31',
#  'IFI6',
#  'EIF2AK3',
#  'RAB9B',
#  'CCDC25',
#  'FRS2',
#  'UEVLD',
#  'CD79B',
#  'SLC35G2',
#  'PHF3',
#  'TAOK1',
#  'C11orf57',
#  'ELMOD3',
#  'TXLNG',
#  'WBSCR27',
#  'CCDC116',
#  'TCF12',
#  'ANGPTL2',
#  'LRBA',
#  'ZBTB3',
#  'CDV3',
#  'LRRC37A',
#  'GNAO1',
#  'LAIR2',
#  'SSUH2',
#  'PTRH1',
#  'ZNF410',
#  'OXR1',
#  'ZBTB2',
#  'SNX32',
#  'PRDM4',
#  'CCDC74B',
#  'RHBDD1',
#  'RP11-297N6.4',
#  'ZNF571',
#  'LSM10',
#  'IL37',
#  'ERN2',
#  'HMSD',
#  'RP11-468E2.4',
#  'PDZRN4',
#  'FBN1',
#  'MTMR12',
#  'CLDN6',
#  'TFAP2B',
#  'SMOC2',
#  'MGST2',
#  'IRF4',
#  'TRNAU1AP',
#  'NCKIPSD',
#  'CFHR1',
#  'GSTM1',
#  'QRFP',
#  'CNR2',
#  'INTS10',
#  'VAMP1',
#  'STOX1',
#  'CHAD',
#  'PLEKHA6',
#  'COMMD1',
#  'PPP2R4',
#  'BLNK',
#  'PSAPL1',
#  'GOLGA6A',
#  'TULP2',
#  'IRGM',
#  'PACS2',
#  'UPK2',
#  'ZNF625',
#  'RP11-268J15.5',
#  'ZFC3H1',
#  'ZNF579',
#  'CTTNBP2',
#  'UQCRQ',
#  'MRP63',
#  'PCDHA5',
#  'AC006132.1',
#  'ACER2',
#  'SPIN2B',
#  'DFNB59',
#  'CASC10',
#  'SPINK6',
#  'IKBKB',
#  'SPIB',
#  'FAM216A',
#  'TMEM120B',
#  'PKIA',
#  'NXPE2',
#  'LRIT3',
#  'LPAR4',
#  'SDCCAG8',
#  'SH2B2',
#  'DHPS',
#  'OS9',
#  'NPIPA7',
#  'PITPNM1',
#  'CYP4F22',
#  'EEPD1',
#  'DPYSL3',
#  'GCNT2',
#  'TBC1D1',
#  'DMWD',
#  'GULP1',
#  'ZBP1',
#  'SERF2',
#  'BPIFB2',
#  'ZNF33A',
#  'PTEN',
#  'ATP6V0E2',
#  'HECA',
#  'GMEB1',
#  'NPTN',
#  'SDS',
#  'CIDEC',
#  'PWWP2B',
#  'MORC3',
#  'CCND2',
#  'CHST4',
#  'CHD5',
#  'C8orf31',
#  'FOCAD',
#  'ETV7',
#  'ZKSCAN2',
#  'CAMK2D',
#  'AC135048.1',
#  'METTL15',
#  'LPAR1',
#  'KLK6',
#  'RMDN1',
#  'AC006538.4',
#  'RAB35',
#  'RBFOX3',
#  'STXBP5',
#  'OTUD3',
#  'ZNF791',
#  'PDLIM7',
#  'SRFBP1',
#  'STXBP4',
#  'KDM2A',
#  'ZSCAN12',
#  'NHLH2',
#  'R3HDML',
#  'ZNF285',
#  'AMFR',
#  'NT5C3A',
#  'C1QL2',
#  'CACUL1',
#  'NECAP1',
#  'GSTA1',
#  'ZSCAN32',
#  'ZNF140',
#  'NKX2-8',
#  'SEPSECS',
#  'ZHX1',
#  'TSKS',
#  'USP6NL',
#  'C20orf196',
#  'ACER3',
#  'MSMB',
#  'RPL27',
#  'AL031663.2',
#  'MMP8',
#  'KCNA1',
#  'USP43',
#  'SLC38A5',
#  'ZNF511',
#  'RDH12',
#  'PUM1',
#  'HTR3E',
#  'ANGPTL4',
#  'PEX5L',
#  'TDGF1',
#  'RGS1',
#  'VNN1',
#  'ARFGAP2',
#  'AC069368.3',
#  'C1orf50',
#  'OSBPL10',
#  'BRD8',
#  'C21orf59',
#  'FOXC2',
#  'CHRNA6',
#  'RP11-598P20.5',
#  'ZNF264',
#  'LCORL',
#  'CSTF2T',
#  'IMPA1',
#  'RANBP9',
#  'FKBP6',
#  'IRS4',
#  'SLC2A14',
#  'CHCHD4',
#  'UVSSA',
#  'DLGAP4',
#  'NUTM2G',
#  'IDO2',
#  'ZNF785',
#  'EBF3',
#  'ADCK1',
#  'NYNRIN',
#  'OBP2A',
#  'UBL7',
#  'APPBP2',
#  'C21orf58',
#  'COQ2',
#  'GPR18',
#  'RRNAD1',
#  'LRP6',
#  'PSTPIP1',
#  'CYP2C9',
#  'CDKN1B',
#  'ZNF644',
#  'ATF7IP2',
#  'PYROXD1',
#  'BAMBI',
#  'TFPI2',
#  'CRAMP1L',
#  'PPP6C',
#  'AL132989.1',
#  'TMED8',
#  'POMP',
#  'PRRT3',
#  'TMTC1',
#  'ZNF281',
#  'SAMD15',
#  'MED4',
#  'ZNF595',
#  'HFE',
#  'TMEM251',
#  'ADCY1',
#  'MICB',
#  'LMF2',
#  'FCER2',
#  'FRMPD1',
#  'NLRP6',
#  'TTC13',
#  'SEC24A',
#  'PLBD2',
#  'RPP38',
#  'CNTN2',
#  'HKR1',
#  'CXXC4',
#  'RFNG',
#  'C1orf61',
#  'WDR73',
#  'ZNF773',
#  'SGK2',
#  'USP11',
#  'MYL2',
#  'USP18',
#  'RNF113A',
#  'C1orf53',
#  'KRTAP5-2',
#  'IMPG2',
#  'FAM134A',
#  'PCDHB2',
#  'ENPP6',
#  'CACNG8',
#  'CCT6B',
#  'NOG',
#  'SELT',
#  'NEIL2',
#  'ATP6V1F',
#  'RNF31',
#  'RPL13',
#  'NPTX2',
#  'HKDC1',
#  'GOLGA2',
#  'CAMK1G',
#  'QPCT',
#  'KCNA2',
#  'IGFN1',
#  'TOR1AIP2',
#  'CYFIP1',
#  'ZBTB17',
#  'IFT43',
#  'COPRS',
#  'RP11-286N22.8',
#  'RHOXF1',
#  'RFC1',
#  'HINT1',
#  'BOC',
#  'AL133373.1',
#  'ENDOU',
#  'NOS1',
#  'CYP3A43',
#  'DZIP1L',
#  'KIAA0319',
#  'CYP1B1',
#  'FAM196A',
#  'TUBA8',
#  'FAM168A',
#  'OPA3',
#  'TSLP',
#  'CXCL11',
#  'LRFN2',
#  'RAD50',
#  'VLDLR',
#  'CASP16',
#  'RP11-542C16.2',
#  'TNFSF9',
#  'PCDHB16',
#  'SLC35C1',
#  'DNPEP',
#  'BAG2',
#  'RAP2C',
#  'HMGN5',
#  'BCAS3',
#  'RNF135',
#  'RNF170',
#  'AP000695.1',
#  'PLK2',
#  'STIM2',
#  'DNAJC25-GNG10',
#  'CTNNBL1',
#  'PDZD8',
#  'PTPN7',
#  'SMARCC2',
#  'TNFRSF17',
#  'TSPAN1',
#  'SUSD3',
#  'MET',
#  'PTMS',
#  'MRPL46',
#  'CCDC112',
#  'RWDD2B',
#  'HSD17B2',
#  'AGFG1',
#  'NIT1',
#  'BSN',
#  'SLC8A2',
#  'LYPLAL1',
#  'GDPGP1',
#  'GRAMD1B',
#  'WEE2',
#  'PCBP3',
#  'SRRM1',
#  'DBNL',
#  'PELI3',
#  'ENC1',
#  'ZFR2',
#  'ZNF575',
#  'ERBB2',
#  'MAFB',
#  'DTX1',
#  'USP6',
#  'MRFAP1L1',
#  'RAB12',
#  'NDUFB7',
#  'C1QTNF1-AS1',
#  'HAPLN2',
#  'MDM4',
#  'RPL15',
#  'SLC5A5',
#  'ELOVL3',
#  'TUB',
#  'DVL1',
#  'C11orf42',
#  'SAMD8',
#  'PCDHGB2',
#  'NHLH1',
#  'PENK',
#  'HCRTR1',
#  'METTL10',
#  'COL2A1',
#  'GPR150',
#  'ZNF394',
#  'AL592284.1',
#  'HGSNAT',
#  'SNCA',
#  'CYB5B',
#  'IRF2BP2',
#  'FAM150A',
#  'PGBD2',
#  'MYO1H',
#  'CXCR5',
#  'ASB13',
#  'C19orf54',
#  'GRIA3',
#  'CNOT4',
#  'NDRG4',
#  'DHDDS',
#  'TIFAB',
#  'KRT40',
#  'RP11-178L8.4',
#  'VTI1B',
#  'LAMTOR5',
#  'DNASE2',
#  'ZNF461',
#  'MATN4',
#  'PDE9A',
#  'EPS8',
#  'CXorf40A',
#  'SEC62',
#  'TNKS',
#  'CDCP2',
#  'ZSCAN5A',
#  'LTN1',
#  'TNKS1BP1',
#  'C3orf80',
#  'IBA57',
#  'ZCCHC18',
#  'RP11-210M15.2',
#  'SSTR2',
#  'TEP1',
#  'PCDHB13',
#  'TAS1R3',
#  'RNF25',
#  'LAMB1',
#  'SLC9A5',
#  'TGM1',
#  'RPL23',
#  'INHBB',
#  'RPL37A',
#  'RPS24',
#  'MIF4GD',
#  'AC011551.3',
#  'NPIPA3',
#  'MFGE8',
#  'ZNF460',
#  'HESX1',
#  'KIAA1432',
#  'ZNF789',
#  'ZADH2',
#  'DEF8',
#  'CHMP4A',
#  'ARL5C',
#  'KCNJ13',
#  'FAM153B',
#  'TAB1',
#  'TERF2',
#  'AKAP3',
#  'FAM221A',
#  'ZNF775',
#  'BEAN1',
#  'RIMBP3',
#  'PDPN',
#  'ALKBH1',
#  'C14orf93',
#  'SLTM',
#  'LUC7L3',
#  'ADRBK1',
#  'RHOBTB3',
#  'CD99',
#  'PAK4',
#  'MRPL49',
#  'OPN1SW',
#  'RBM14-RBM4',
#  'ZNF552',
#  'GSDMA',
#  'C16orf52',
#  'RP11-41O4.1',
#  'CXorf58',
#  'SRA1',
#  'PRSS36',
#  'LRRC17',
#  'ZNF117',
#  'RP11-343C2.11',
#  'SP4',
#  'BTG4',
#  'CPA5',
#  'NIPSNAP3B',
#  'LDLRAP1',
#  'SNX7',
#  'SAMD11',
#  'CTSA',
#  'NSMAF',
#  'FAM212A',
#  'ACSL6',
#  'PTPN20A',
#  'NIPAL2',
#  'TMSB4Y',
#  'FRG1B',
#  'CASQ1',
#  'PROSER1',
#  'CECR2',
#  'SPATA22',
#  'GALK1',
#  'YRDC',
#  'MEGF11',
#  'VMAC',
#  'MATR3',
#  'DHRSX',
#  'BVES',
#  'OFD1',
#  'AIRE',
#  'RAB3IL1',
#  'ARL5A',
#  'ZNF814',
#  'SULT1B1',
#  'INPP5J',
#  'CENPC',
#  'SPINK2',
#  'COQ6',
#  ...]

# %%
'There are '+str (len(rep_r))+' rejected genes as paired'
# Out:
# 'There are 12693 rejected genes as paired'

# %%
repgenes_r

# %%
##correction

#2b

# %%
#for independent
corrected_pi_values = multipletests(p_values_i, alpha=0.05, method='fdr_bh')[1]

#for paired
corrected_pr_values = multipletests(p_values_r, alpha=0.05, method='fdr_bh')[1]

# %%
'Independent corrected values : ', corrected_pi_values

# %%
'Paired corrected values : ', corrected_pr_values

# %%
# gene_names = ['G' + str(i) for i in range(1, len(p_values_i))]
significance_genes_i = pd.DataFrame({'p-values-independent':p_values_i, 'p-values_i_fdr':corrected_pi_values})
significance_genes_r = pd.DataFrame({'p-values-paired':p_values_r, 'p-values_r_fdr':corrected_pr_values})

# %%
significance_genes_i
# Out:
#        p-values-independent  p-values_i_fdr
# 0              3.607140e-09    1.373146e-08
# 1              3.138295e-01    3.634380e-01
# 2              8.164044e-05    1.718039e-04
# 3              6.374652e-15    5.016953e-14
# 4              4.726590e-02    6.500943e-02
# ...                     ...             ...
# 17270          2.273493e-06    5.975140e-06
# 17271          5.250215e-08    1.714832e-07
# 17272          1.228186e-14    9.305663e-14
# 17273          1.068283e-12    6.277074e-12
# 17274          2.133666e-07    6.428162e-07
#
# [17275 rows x 2 columns]

# %%
significance_genes_r
# Out:
#        p-values-paired  p-values_r_fdr
# 0         4.043607e-08    1.448337e-07
# 1         2.891646e-01    3.361135e-01
# 2         2.322367e-04    4.579260e-04
# 3         3.420577e-12    2.445798e-11
# 4         6.251346e-02    8.352696e-02
# ...                ...             ...
# 17270     4.142164e-06    1.081558e-05
# 17271     2.452619e-07    7.755627e-07
# 17272     2.435125e-13    2.159486e-12
# 17273     4.129496e-11    2.418205e-10
# 17274     1.166719e-06    3.324822e-06
#
# [17275 rows x 2 columns]

# %%
significance_genes_i['significance:p_vlaue_i'] = significance_genes_i['p-values-independent'].apply(lambda x: x < 0.05)
significance_genes_i['significance:p_vlaue_i_fdr'] = significance_genes_i['p-values_i_fdr'].apply(lambda x: x < 0.05)
significance_genes_i
# Out:
#        p-values-independent  p-values_i_fdr  significance:p_vlaue_i  \
# 0              3.607140e-09    1.373146e-08                    True
# 1              3.138295e-01    3.634380e-01                   False
# 2              8.164044e-05    1.718039e-04                    True
# 3              6.374652e-15    5.016953e-14                    True
# 4              4.726590e-02    6.500943e-02                    True
# ...                     ...             ...                     ...
# 17270          2.273493e-06    5.975140e-06                    True
# 17271          5.250215e-08    1.714832e-07                    True
# 17272          1.228186e-14    9.305663e-14                    True
# 17273          1.068283e-12    6.277074e-12                    True
# 17274          2.133666e-07    6.428162e-07                    True
#
#        significance:p_vlaue_i_fdr
# 0                            True
# 1                           False
# 2                            True
# 3                            True
# 4                           False
# ...                           ...
# 17270                        True
# 17271                        True
# 17272                        True
# 17273                        True
# 17274                        True
#
# [17275 rows x 4 columns]

# %%
significance_genes_r['significance:p_vlaue_r'] = significance_genes_r['p-values-paired'].apply(lambda x: x < 0.05)
significance_genes_r['significance:p_vlaue_r_fdr'] = significance_genes_r['p-values_r_fdr'].apply(lambda x: x < 0.05)
significance_genes_r
# Out:
#        p-values-paired  p-values_r_fdr  significance:p_vlaue_r  \
# 0         4.043607e-08    1.448337e-07                    True
# 1         2.891646e-01    3.361135e-01                   False
# 2         2.322367e-04    4.579260e-04                    True
# 3         3.420577e-12    2.445798e-11                    True
# 4         6.251346e-02    8.352696e-02                   False
# ...                ...             ...                     ...
# 17270     4.142164e-06    1.081558e-05                    True
# 17271     2.452619e-07    7.755627e-07                    True
# 17272     2.435125e-13    2.159486e-12                    True
# 17273     4.129496e-11    2.418205e-10                    True
# 17274     1.166719e-06    3.324822e-06                    True
#
#        significance:p_vlaue_r_fdr
# 0                            True
# 1                           False
# 2                            True
# 3                            True
# 4                           False
# ...                           ...
# 17270                        True
# 17271                        True
# 17272                        True
# 17273                        True
# 17274                        True
#
# [17275 rows x 4 columns]

# %%
significance_genes_i.to_csv("data/significance_genes_i.csv")

# %%
significance_genes_r.to_csv("data/significance_genes_r.csv")

# %%
diffrentially_genes_i.to_csv("data/diffrentially_genes_i.csv")

# %%
diffrentially_genes_r.to_csv("data/diffrentially_genes_r.csv")

# %%
# Get significant genes after fdr correction
diffrentially_genes_i = significance_genes_i[significance_genes_i['significance:p_vlaue_i_fdr']== True]

# %%
diffrentially_genes_i
# Out:
#        p-values-independent  p-values_i_fdr  significance:p_vlaue_i  \
# 0              3.607140e-09    1.373146e-08                    True
# 2              8.164044e-05    1.718039e-04                    True
# 3              6.374652e-15    5.016953e-14                    True
# 6              5.344289e-06    1.333949e-05                    True
# 7              7.857877e-06    1.917029e-05                    True
# ...                     ...             ...                     ...
# 17270          2.273493e-06    5.975140e-06                    True
# 17271          5.250215e-08    1.714832e-07                    True
# 17272          1.228186e-14    9.305663e-14                    True
# 17273          1.068283e-12    6.277074e-12                    True
# 17274          2.133666e-07    6.428162e-07                    True
#
#        significance:p_vlaue_i_fdr
# 0                            True
# 2                            True
# 3                            True
# 6                            True
# 7                            True
# ...                           ...
# 17270                        True
# 17271                        True
# 17272                        True
# 17273                        True
# 17274                        True
#
# [12290 rows x 4 columns]

# %%
diffrentially_genes_i.to_csv("data/diffrentially_genes_i.csv")

# %%
# Get significant genes after fdr correction
diffrentially_genes_r = significance_genes_r[significance_genes_r['significance:p_vlaue_r_fdr']== True]
diffrentially_genes_r
# Out:
#        p-values-paired  p-values_r_fdr  significance:p_vlaue_r  \
# 0         4.043607e-08    1.448337e-07                    True
# 2         2.322367e-04    4.579260e-04                    True
# 3         3.420577e-12    2.445798e-11                    True
# 6         3.041721e-06    8.115171e-06                    True
# 7         1.938575e-05    4.547030e-05                    True
# ...                ...             ...                     ...
# 17270     4.142164e-06    1.081558e-05                    True
# 17271     2.452619e-07    7.755627e-07                    True
# 17272     2.435125e-13    2.159486e-12                    True
# 17273     4.129496e-11    2.418205e-10                    True
# 17274     1.166719e-06    3.324822e-06                    True
#
#        significance:p_vlaue_r_fdr
# 0                            True
# 2                            True
# 3                            True
# 6                            True
# 7                            True
# ...                           ...
# 17270                        True
# 17271                        True
# 17272                        True
# 17273                        True
# 17274                        True
#
# [12380 rows x 4 columns]

# %%
#2c

# %%
#after applying correction method, we need to know the genes which has p<0.05 after correction
corrected_rejection_i = [] # here, we make a new list of corrected independent p values whose p<0.05, that will reject H0
corrected_rejection_r = [] # here, we make a new list of corrected paired p values whose p<0.05, that will reject H0

genes_corrected_rejection_i = [] # here, we make a new 'gene' list of corrected independent values whose p<0.05, that will reject H0
genes_corrected_rejection_r = [] # here, we make a new 'gene' list of corrected paired values whose p<0.05, that will reject H0

# %%
for q in range(len(healthy2)):

    if corrected_pr_values[q] < 0.05:
        corrected_rejection_r.append(corrected_pr_values[q])
        genes_corrected_rejection_r.append(healthy2.iloc[q, 0])

    if corrected_pi_values[q] < 0.05:
        corrected_rejection_i.append(corrected_pi_values[q])
        genes_corrected_rejection_i.append(healthy2.iloc[q, 0])

# %%
#priniting lists of independent and paired genes in rejection region after correction
'Independent corrected rejection genes : ', genes_corrected_rejection_i

# %%
'Paired corrected rejection genes : ', genes_corrected_rejection_r

# %%
#2d

genes_set_r = set(genes_corrected_rejection_r) # list conversion to set to apply builtin fns of sets
genes_set_i = set(genes_corrected_rejection_i)

intersect = genes_set_r.intersection(genes_set_i) # intersected genes
diff_ri = genes_set_r.difference(genes_set_i)  # r diff from i
diff_ir = genes_set_i.difference(genes_set_r)  # i diff from r

# %%
intersect = list(intersect)
common_genes = pd.DataFrame({'intersected':intersect})

# %%
common_genes
# Out:
#       intersected
# 0          B3GNT1
# 1           STRA6
# 2         RNF144B
# 3           CBWD3
# 4          PLSCR4
# ...           ...
# 12206   HIST2H2BE
# 12207        IDNK
# 12208      TNNI3K
# 12209     WFIKKN1
# 12210        PSD3
#
# [12211 rows x 1 columns]

# %%
diff_ri = list(diff_ri)
diff_ri_genes = pd.DataFrame({'diff_ri':diff_ri})
diff_ri_genes
# Out:
#           diff_ri
# 0           KRT79
# 1             GAA
# 2         NADSYN1
# 3       C20orf201
# 4           EIF3C
# ..            ...
# 164           GPT
# 165       ST8SIA1
# 166  RP13-996F3.5
# 167         GSDMB
# 168        HIVEP2
#
# [169 rows x 1 columns]

# %%
diff_ir = list(diff_ir)
diff_ir_genes = pd.DataFrame({'diff_ir':diff_ir})
diff_ir_genes
# Out:
#     diff_ir
# 0   PGPEP1L
# 1    SHKBP1
# 2    FKBP1A
# 3     ITSN1
# 4    LRRC31
# ..      ...
# 74   NANOS3
# 75    VPRBP
# 76  RPS6KA6
# 77     GJA9
# 78   SPECC1
#
# [79 rows x 1 columns]

# %%
len(genes_set_r)
# Out:
# 12380

# %%
len(genes_set_i)
# Out:
# 12290

# %%
'independent intersected with paired = ', len(intersect)
# Out:
# ('independent intersected with paired = ', 12211)

# %%
'paired - independent = ', len(diff_ri)
# Out:
# ('paired - independent = ', 169)

# %%
'independent - paired = ', len(diff_ir)
# Out:
# ('independent - paired = ', 79)
